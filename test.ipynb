# %%
import torch
import torchvision.transforms as transforms
from torchvision import datasets, models
from torch.utils.data import DataLoader

# Step 1: Load the pretrained model
model = models.alexnet(pretrained=True)
model.eval()  # Set the model to evaluation mode

# Step 2: Prepare the CIFAR10 dataset
transform = transforms.Compose(
    [
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ]
)

# Load CIFAR10
train_dataset = datasets.CIFAR10(
    root="./data", train=True, download=True, transform=transform
)
test_dataset = datasets.CIFAR10(
    root="./data", train=False, download=True, transform=transform
)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)


# Step 3: Define the evaluation metric
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, 1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))


# Step 4: Evaluate the model on the test set
total_accuracy = 0
total_samples = 0

with torch.no_grad():  # Disable gradient computation
    for images, labels in test_loader:
        outputs = model(images)
        total_accuracy += accuracy(outputs, labels) * images.size(0)
        total_samples += images.size(0)

print(f"Accuracy: {total_accuracy/total_samples:.2f}")
# Out:
# Files already downloaded and verified
# Shape of images: torch.Size([10, 3, 224, 224])
# Labels: tensor([3, 8, 8, 0, 6, 6, 1, 6, 3, 1])
# Model outputs: tensor([[ 0.6175,  1.2068,  0.4165, -0.0327,  1.0109, -0.4699, -0.0486,  0.7053,
#           0.5276,  0.8022],
#         [ 0.0945,  1.4550,  0.2541, -1.1134,  0.7000, -0.1805, -0.6558,  0.4922,
#           0.5821,  0.4114],
#         [ 1.2710,  0.4897,  0.0044, -0.5899,  1.3828, -0.0667, -0.6573,  1.0354,
#           0.8861,  0.7321],
#         [-0.0291,  0.9328,  0.6547, -0.8127,  1.1128, -0.0328, -0.3471,  0.5694,
#           0.1890,  0.6997],
#         [-0.3130,  1.1678,  0.7404, -0.0439,  0.6904,  0.4394, -0.4430,  0.8653,
#           0.2046,  1.4180],
#         [ 0.0153,  0.6478,  0.3468,  0.7277,  1.3743,  0.3285,  0.3513,  0.2923,
#           0.5868,  1.1714],
#         [ 0.3656,  0.8359,  0.8290,  0.3245,  1.1494, -0.0671,  0.1716, -0.2312,
#           0.9066,  1.3271],
#         [-0.1869,  0.9709,  0.4063, -0.1205,  1.0908, -0.0941, -0.7757,  0.8036,
#           0.0904,  0.5794],
#         [-0.1337,  0.4449,  0.3734,  0.0622,  0.6248,  0.1156,  0.4666,  0.3683,
#           1.0010,  0.3824],
#         [ 0.4280,  1.1918,  0.4735, -0.3422,  1.1831,  0.5628, -0.2464,  0.6786,
#           1.0893,  0.6435]], grad_fn=<AddmmBackward0>)
# Predicted labels: tensor([1, 1, 4, 4, 9, 4, 9, 4, 8, 1])
# Batch predicted: tensor([1, 1, 4, 4, 9, 4, 9, 4, 8, 1])
# Batch labels: tensor([3, 8, 8, 0, 6, 6, 1, 6, 3, 1])
# Batch predicted: tensor([1, 1, 1, 1, 1, 1, 4, 1, 4, 9])
# Batch labels: tensor([0, 9, 5, 7, 9, 8, 5, 7, 8, 6])
# Batch predicted: tensor([4, 4, 4, 1, 1, 1, 4, 1, 1, 9])
# Batch labels: tensor([7, 0, 4, 9, 5, 2, 4, 0, 9, 6])
# Batch predicted: tensor([9, 1, 4, 2, 4, 1, 4, 4, 1, 4])
# Batch labels: tensor([6, 5, 4, 5, 9, 2, 4, 1, 9, 5])
# Batch predicted: tensor([4, 9, 1, 8, 4, 1, 2, 1, 4, 7])
# Batch labels: tensor([4, 6, 5, 6, 0, 9, 3, 9, 7, 6])
# Batch predicted: tensor([4, 7, 7, 4, 4, 4, 4, 1, 1, 9])
# Batch labels: tensor([9, 8, 0, 3, 8, 8, 7, 7, 4, 6])
# Batch predicted: tensor([4, 4, 4, 8, 4, 9, 8, 4, 4, 9])
# Batch labels: tensor([7, 3, 6, 3, 6, 2, 1, 2, 3, 7])
# Batch predicted: tensor([9, 4, 1, 4, 0, 1, 2, 1, 1, 4])
# Batch labels: tensor([2, 6, 8, 8, 0, 2, 9, 3, 3, 8])
# Batch predicted: tensor([4, 4, 4, 8, 4, 1, 2, 1, 4, 1])
# Batch labels: tensor([8, 1, 1, 7, 2, 5, 2, 7, 8, 9])
# Batch predicted: tensor([1, 9, 1, 9, 8, 4, 4, 7, 4, 2])
# Batch labels: tensor([0, 3, 8, 6, 4, 6, 6, 0, 0, 7])
# Batch predicted: tensor([4, 4, 3, 2, 1, 4, 4, 7, 4, 1])
# Batch labels: tensor([4, 5, 6, 3, 1, 1, 3, 6, 8, 7])
# Batch predicted: tensor([9, 4, 1, 9, 1, 8, 4, 9, 9, 1])
# Batch labels: tensor([4, 0, 6, 2, 1, 3, 0, 4, 2, 7])
# Batch predicted: tensor([8, 9, 4, 4, 7, 4, 2, 9, 1, 4])
# Batch labels: tensor([8, 3, 1, 2, 8, 0, 8, 3, 5, 2])
# Batch predicted: tensor([9, 1, 1, 1, 4, 1, 4, 1, 9, 1])
# Batch labels: tensor([4, 1, 8, 9, 1, 2, 9, 7, 2, 9])
# Batch predicted: tensor([9, 1, 4, 1, 1, 1, 4, 9, 4, 1])
# Batch labels: tensor([6, 5, 6, 3, 8, 7, 6, 2, 5, 2])
# Batch predicted: tensor([1, 1, 9, 4, 4, 4, 9, 4, 1, 4])
# Batch labels: tensor([8, 9, 6, 0, 0, 5, 2, 9, 5, 4])
# Batch predicted: tensor([4, 4, 4, 7, 7, 4, 7, 7, 9, 7])
# Batch labels: tensor([2, 1, 6, 6, 8, 4, 8, 4, 5, 0])
# Batch predicted: tensor([4, 4, 4, 4, 1, 4, 4, 4, 9, 4])
# Batch labels: tensor([9, 9, 9, 8, 9, 9, 3, 7, 5, 0])
# Batch predicted: tensor([4, 4, 7, 9, 8, 4, 9, 1, 8, 2])
# Batch labels: tensor([0, 5, 2, 2, 3, 8, 6, 3, 4, 0])
# Batch predicted: tensor([9, 7, 1, 4, 4, 8, 4, 4, 8, 1])
# Batch labels: tensor([5, 8, 0, 1, 7, 2, 8, 8, 7, 8])
# Batch predicted: tensor([8, 0, 1, 4, 4, 9, 4, 4, 4, 4])
# Batch labels: tensor([5, 1, 8, 7, 1, 3, 0, 5, 7, 9])
# Batch predicted: tensor([4, 9, 1, 4, 1, 1, 8, 1, 1, 4])
# Batch labels: tensor([7, 4, 5, 9, 8, 0, 7, 9, 8, 2])
# Batch predicted: tensor([4, 9, 1, 7, 2, 2, 7, 4, 9, 4])
# Batch labels: tensor([7, 6, 9, 4, 3, 9, 6, 4, 7, 6])
# Batch predicted: tensor([1, 1, 4, 7, 1, 1, 9, 1, 9, 4])
# Batch labels: tensor([5, 1, 5, 8, 8, 0, 4, 0, 5, 5])
# Batch predicted: tensor([1, 4, 1, 1, 4, 4, 1, 1, 1, 1])
# Batch labels: tensor([1, 1, 8, 9, 0, 3, 1, 9, 2, 2])
# Batch predicted: tensor([3, 9, 4, 4, 4, 1, 7, 1, 4, 1])
# Batch labels: tensor([5, 3, 9, 9, 4, 0, 3, 0, 0, 9])
# Batch predicted: tensor([4, 1, 7, 4, 4, 8, 2, 4, 4, 2])
# Batch labels: tensor([8, 1, 5, 7, 0, 8, 2, 4, 7, 0])
# Batch predicted: tensor([4, 1, 4, 4, 4, 9, 0, 2, 4, 8])
# Batch labels: tensor([2, 3, 6, 3, 8, 5, 0, 3, 4, 3])
# Batch predicted: tensor([4, 1, 4, 1, 1, 4, 4, 7, 4, 1])
# Batch labels: tensor([9, 0, 6, 1, 0, 9, 1, 0, 7, 9])
# Batch predicted: tensor([4, 9, 4, 4, 4, 4, 4, 4, 1, 4])
# Batch labels: tensor([1, 2, 6, 9, 3, 4, 6, 0, 0, 6])
# Batch predicted: tensor([4, 4, 4, 8, 9, 1, 1, 7, 4, 7])
# Batch labels: tensor([6, 6, 3, 2, 6, 1, 8, 2, 1, 6])
# Batch predicted: tensor([7, 9, 4, 1, 7, 4, 8, 4, 4, 1])
# Batch labels: tensor([8, 6, 8, 0, 4, 0, 7, 7, 5, 5])
# Batch predicted: tensor([7, 8, 9, 9, 4, 8, 2, 4, 9, 9])
# Batch labels: tensor([3, 5, 2, 3, 4, 1, 7, 5, 4, 6])
# Batch predicted: tensor([4, 1, 7, 4, 9, 4, 4, 4, 4, 1])
# Batch labels: tensor([1, 9, 3, 6, 6, 9, 3, 8, 0, 7])
# Batch predicted: tensor([4, 4, 1, 1, 1, 1, 4, 4, 7, 1])
# Batch labels: tensor([2, 6, 2, 5, 8, 5, 4, 6, 8, 9])
# Batch predicted: tensor([4, 8, 1, 1, 4, 4, 9, 2, 7, 1])
# Batch labels: tensor([9, 1, 0, 2, 2, 7, 3, 2, 8, 0])
# Batch predicted: tensor([2, 4, 7, 4, 2, 7, 7, 4, 1, 1])
# Batch labels: tensor([9, 5, 8, 1, 9, 4, 1, 3, 8, 1])
# Batch predicted: tensor([4, 1, 1, 9, 1, 4, 4, 4, 4, 4])
# Batch labels: tensor([4, 7, 9, 4, 2, 7, 0, 7, 0, 6])
# Batch predicted: tensor([9, 1, 4, 1, 1, 1, 4, 4, 2, 2])
# Batch labels: tensor([6, 9, 0, 9, 2, 8, 7, 2, 2, 5])
# Batch predicted: tensor([4, 1, 9, 1, 1, 9, 8, 1, 4, 7])
# Batch labels: tensor([1, 2, 6, 2, 9, 6, 2, 3, 0, 3])
# Batch predicted: tensor([1, 1, 4, 7, 1, 7, 1, 4, 7, 2])
# Batch labels: tensor([9, 8, 7, 8, 8, 4, 0, 1, 8, 2])
# Batch predicted: tensor([1, 1, 4, 9, 1, 1, 4, 1, 2, 1])
# Batch labels: tensor([7, 9, 3, 6, 1, 9, 0, 7, 3, 7])
# Batch predicted: tensor([4, 7, 1, 4, 7, 4, 1, 8, 1, 4])
# Batch labels: tensor([4, 5, 0, 0, 2, 9, 3, 4, 0, 6])
# Batch predicted: tensor([8, 9, 4, 4, 9, 4, 7, 4, 1, 9])
# Batch labels: tensor([2, 5, 3, 7, 3, 7, 2, 5, 3, 1])
# Batch predicted: tensor([1, 7, 1, 1, 9, 8, 9, 4, 4, 1])
# Batch labels: tensor([1, 4, 9, 9, 5, 7, 5, 0, 2, 2])
# Batch predicted: tensor([1, 1, 9, 9, 4, 7, 7, 4, 2, 1])
# Batch labels: tensor([2, 9, 7, 3, 9, 4, 3, 5, 4, 6])
# Batch predicted: tensor([2, 7, 4, 7, 9, 4, 4, 2, 9, 7])
# Batch labels: tensor([5, 6, 1, 4, 3, 4, 4, 3, 7, 8])
# Batch predicted: tensor([8, 1, 4, 1, 2, 4, 7, 1, 1, 9])
# Batch labels: tensor([3, 7, 8, 0, 5, 7, 6, 0, 5, 4])
# Batch predicted: tensor([1, 9, 4, 1, 2, 4, 4, 1, 9, 4])
# Batch labels: tensor([8, 6, 8, 5, 5, 9, 9, 9, 5, 0])
# Batch predicted: tensor([0, 1, 7, 4, 1, 4, 1, 9, 4, 4])
# Batch labels: tensor([1, 0, 8, 1, 1, 8, 0, 2, 2, 0])
# Batch predicted: tensor([7, 4, 4, 9, 1, 8, 4, 1, 4, 7])
# Batch labels: tensor([4, 6, 5, 4, 9, 4, 7, 9, 9, 4])
# Batch predicted: tensor([9, 9, 9, 4, 1, 8, 4, 1, 1, 4])
# Batch labels: tensor([5, 6, 6, 1, 5, 3, 8, 9, 5, 8])
# Batch predicted: tensor([1, 4, 1, 2, 1, 9, 4, 4, 4, 4])
# Batch labels: tensor([5, 7, 0, 7, 0, 5, 0, 0, 4, 6])
# Batch predicted: tensor([4, 4, 4, 9, 7, 4, 7, 7, 1, 1])
# Batch labels: tensor([9, 0, 9, 5, 6, 6, 6, 2, 9, 0])
# Batch predicted: tensor([1, 2, 7, 9, 9, 4, 1, 9, 9, 1])
# Batch labels: tensor([1, 7, 6, 7, 5, 9, 1, 6, 2, 5])
# Batch predicted: tensor([2, 4, 1, 7, 1, 1, 7, 4, 2, 1])
# Batch labels: tensor([5, 5, 8, 5, 9, 4, 6, 4, 3, 2])
# Batch predicted: tensor([4, 4, 4, 9, 4, 1, 1, 9, 7, 1])
# Batch labels: tensor([0, 7, 6, 2, 2, 3, 9, 7, 9, 2])
# Batch predicted: tensor([9, 4, 4, 7, 9, 9, 4, 4, 1, 1])
# Batch labels: tensor([6, 7, 1, 3, 6, 6, 8, 9, 7, 5])
# Batch predicted: tensor([4, 7, 1, 4, 4, 4, 4, 4, 4, 4])
# Batch labels: tensor([4, 0, 8, 4, 0, 9, 3, 4, 8, 9])
# Batch predicted: tensor([9, 4, 9, 9, 7, 4, 1, 8, 1, 9])
# Batch labels: tensor([6, 9, 2, 6, 1, 4, 7, 3, 5, 3])
# Batch predicted: tensor([1, 9, 4, 7, 4, 4, 1, 4, 2, 1])
# Batch labels: tensor([8, 5, 0, 2, 1, 6, 4, 3, 3, 9])
# Batch predicted: tensor([9, 1, 1, 7, 4, 4, 7, 9, 4, 4])
# Batch labels: tensor([6, 9, 8, 8, 5, 8, 6, 6, 2, 1])
# Batch predicted: tensor([4, 1, 0, 4, 1, 4, 7, 4, 4, 1])
# Batch labels: tensor([7, 7, 1, 2, 7, 9, 9, 4, 4, 1])
# Batch predicted: tensor([7, 4, 9, 4, 1, 4, 7, 9, 7, 1])
# Batch labels: tensor([2, 5, 6, 8, 7, 6, 8, 3, 0, 5])
# Batch predicted: tensor([1, 9, 1, 4, 4, 1, 1, 7, 4, 1])
# Batch labels: tensor([5, 3, 0, 7, 9, 1, 3, 4, 4, 5])
# Batch predicted: tensor([4, 1, 4, 9, 1, 1, 1, 8, 4, 7])
# Batch labels: tensor([3, 9, 5, 6, 9, 2, 1, 1, 4, 1])
# Batch predicted: tensor([1, 4, 8, 9, 4, 4, 1, 1, 1, 8])
# Batch labels: tensor([9, 4, 7, 6, 3, 8, 9, 0, 1, 3])
# Batch predicted: tensor([4, 1, 9, 4, 4, 1, 2, 9, 1, 1])
# Batch labels: tensor([6, 3, 6, 3, 2, 0, 3, 1, 0, 5])
# Batch predicted: tensor([1, 4, 7, 1, 4, 7, 4, 4, 7, 4])
# Batch labels: tensor([9, 6, 4, 8, 9, 6, 9, 6, 3, 0])
# Batch predicted: tensor([8, 4, 4, 2, 1, 9, 4, 4, 4, 1])
# Batch labels: tensor([3, 2, 2, 7, 8, 3, 8, 2, 7, 5])
# Batch predicted: tensor([8, 1, 9, 1, 2, 9, 4, 9, 7, 0])
# Batch labels: tensor([7, 2, 4, 8, 7, 4, 2, 9, 8, 8])
# Batch predicted: tensor([4, 1, 7, 4, 4, 2, 9, 4, 9, 8])
# Batch labels: tensor([6, 8, 8, 7, 4, 3, 3, 8, 4, 9])
# Batch predicted: tensor([4, 4, 4, 4, 4, 1, 4, 8, 9, 4])
# Batch labels: tensor([4, 8, 8, 1, 8, 2, 1, 3, 6, 5])
# Batch predicted: tensor([4, 1, 8, 4, 1, 9, 4, 4, 1, 1])
# Batch labels: tensor([4, 2, 7, 9, 9, 4, 1, 4, 1, 3])
# Batch predicted: tensor([1, 1, 4, 4, 8, 8, 1, 4, 4, 9])
# Batch labels: tensor([2, 7, 0, 7, 9, 7, 6, 6, 2, 5])
# Batch predicted: tensor([1, 4, 4, 4, 4, 4, 9, 7, 7, 8])
# Batch labels: tensor([9, 2, 9, 1, 2, 2, 6, 8, 2, 1])
# Batch predicted: tensor([8, 9, 7, 1, 1, 4, 7, 1, 4, 9])
# Batch labels: tensor([3, 6, 6, 0, 1, 2, 7, 0, 5, 4])
# Batch predicted: tensor([8, 1, 9, 2, 4, 7, 8, 4, 4, 7])
# Batch labels: tensor([6, 1, 6, 4, 0, 2, 2, 6, 0, 5])
# Batch predicted: tensor([1, 4, 1, 4, 2, 1, 8, 1, 4, 4])
# Batch labels: tensor([9, 1, 7, 6, 7, 0, 3, 9, 6, 8])
# Batch predicted: tensor([1, 1, 1, 4, 4, 1, 4, 7, 8, 7])
# Batch labels: tensor([3, 0, 3, 4, 7, 7, 1, 4, 7, 2])
# Batch predicted: tensor([2, 1, 4, 1, 7, 4, 1, 4, 4, 1])
# Batch labels: tensor([7, 1, 4, 7, 4, 4, 8, 4, 7, 7])
# Batch predicted: tensor([1, 4, 4, 4, 4, 4, 1, 4, 1, 8])
# Batch labels: tensor([5, 3, 7, 2, 0, 8, 9, 5, 8, 3])
# Batch predicted: tensor([7, 4, 1, 1, 1, 1, 1, 2, 4, 1])
# Batch labels: tensor([6, 2, 0, 8, 7, 3, 7, 6, 5, 3])
# Batch predicted: tensor([1, 9, 9, 4, 1, 2, 4, 1, 1, 4])
# Batch labels: tensor([1, 3, 2, 2, 5, 4, 1, 2, 9, 2])
# Batch predicted: tensor([8, 4, 8, 4, 8, 1, 4, 1, 9, 9])
# Batch labels: tensor([7, 0, 7, 2, 1, 3, 2, 0, 2, 4])
# Batch predicted: tensor([4, 4, 1, 1, 4, 4, 4, 1, 8, 4])
# Batch labels: tensor([7, 9, 8, 9, 0, 7, 7, 0, 7, 8])
# Batch predicted: tensor([4, 7, 2, 1, 4, 4, 4, 4, 0, 1])
# Batch labels: tensor([4, 6, 3, 3, 0, 1, 3, 7, 0, 1])
# Batch predicted: tensor([8, 4, 4, 4, 8, 1, 9, 2, 1, 4])
# Batch labels: tensor([3, 1, 4, 2, 3, 8, 4, 2, 3, 7])
# Batch predicted: tensor([1, 7, 1, 1, 1, 4, 1, 4, 9, 7])
# Batch labels: tensor([8, 4, 3, 0, 9, 0, 0, 1, 0, 4])
# Batch predicted: tensor([7, 7, 2, 7, 1, 8, 2, 4, 1, 1])
# Batch labels: tensor([4, 6, 7, 6, 1, 1, 3, 7, 3, 5])
# Batch predicted: tensor([4, 9, 9, 9, 4, 4, 4, 4, 1, 1])
# Batch labels: tensor([2, 6, 6, 5, 8, 7, 1, 6, 8, 8])
# Batch predicted: tensor([4, 8, 1, 6, 4, 0, 9, 1, 4, 1])
# Batch labels: tensor([5, 3, 0, 4, 0, 1, 3, 8, 8, 0])
# Batch predicted: tensor([9, 1, 2, 4, 8, 1, 1, 9, 1, 4])
# Batch labels: tensor([6, 9, 9, 9, 5, 5, 8, 6, 0, 0])
# Batch predicted: tensor([4, 1, 8, 9, 4, 2, 7, 1, 7, 1])
# Batch labels: tensor([4, 2, 3, 2, 7, 2, 2, 5, 9, 8])
# Batch predicted: tensor([1, 4, 4, 7, 4, 1, 1, 4, 7, 4])
# Batch labels: tensor([9, 1, 7, 4, 0, 3, 0, 1, 3, 8])
# Batch predicted: tensor([8, 1, 1, 8, 9, 8, 4, 4, 4, 1])
# Batch labels: tensor([3, 9, 6, 1, 4, 7, 0, 3, 7, 8])
# Batch predicted: tensor([4, 1, 1, 9, 7, 1, 4, 1, 4, 4])
# Batch labels: tensor([9, 1, 1, 6, 6, 6, 6, 9, 1, 9])
# Batch predicted: tensor([1, 4, 7, 1, 4, 4, 4, 1, 1, 1])
# Batch labels: tensor([9, 4, 2, 1, 7, 0, 6, 8, 1, 9])
# Batch predicted: tensor([4, 4, 4, 4, 1, 4, 1, 4, 4, 4])
# Batch labels: tensor([2, 9, 0, 4, 7, 8, 3, 1, 2, 0])
# Batch predicted: tensor([4, 4, 1, 4, 9, 8, 7, 4, 8, 1])
# Batch labels: tensor([1, 5, 8, 4, 6, 3, 8, 1, 3, 8])
# Batch predicted: tensor([9, 1, 4, 4, 2, 4, 4, 1, 1, 4])
# Batch labels: tensor([5, 0, 8, 4, 8, 1, 1, 8, 9, 6])
# Batch predicted: tensor([4, 2, 9, 4, 1, 7, 1, 9, 1, 9])
# Batch labels: tensor([0, 8, 6, 1, 3, 4, 1, 6, 0, 5])
# Batch predicted: tensor([1, 4, 1, 1, 8, 1, 4, 4, 9, 9])
# Batch labels: tensor([1, 1, 0, 0, 3, 5, 0, 0, 6, 6])
# Batch predicted: tensor([1, 2, 4, 2, 4, 4, 4, 1, 1, 7])
# Batch labels: tensor([3, 3, 6, 3, 6, 6, 0, 7, 2, 2])
# Batch predicted: tensor([4, 1, 1, 1, 0, 2, 9, 4, 4, 3])
# Batch labels: tensor([7, 5, 5, 2, 8, 5, 2, 1, 1, 4])
# Batch predicted: tensor([1, 4, 1, 1, 1, 9, 8, 1, 9, 7])
# Batch labels: tensor([3, 2, 0, 3, 1, 5, 3, 7, 6, 8])
# Batch predicted: tensor([4, 1, 4, 9, 8, 8, 4, 4, 1, 7])
# Batch labels: tensor([9, 1, 6, 4, 9, 3, 9, 0, 9, 6])
# Batch predicted: tensor([8, 7, 1, 8, 2, 7, 1, 4, 1, 9])
# Batch labels: tensor([3, 6, 0, 7, 3, 8, 0, 0, 0, 6])
# Batch predicted: tensor([7, 9, 4, 1, 9, 4, 4, 9, 1, 9])
# Batch labels: tensor([6, 6, 9, 2, 5, 4, 4, 6, 3, 6])
# Batch predicted: tensor([7, 1, 9, 1, 1, 9, 4, 1, 1, 4])
# Batch labels: tensor([0, 8, 6, 0, 6, 2, 7, 5, 1, 2])
# Batch predicted: tensor([1, 1, 1, 2, 4, 8, 1, 1, 1, 1])
# Batch labels: tensor([7, 8, 8, 0, 9, 4, 9, 7, 2, 0])
# Batch predicted: tensor([4, 7, 1, 1, 4, 4, 4, 8, 4, 1])
# Batch labels: tensor([2, 8, 3, 8, 9, 1, 5, 5, 4, 7])
# Batch predicted: tensor([1, 4, 7, 8, 7, 9, 1, 4, 2, 4])
# Batch labels: tensor([5, 3, 8, 3, 3, 6, 2, 8, 4, 3])
# Batch predicted: tensor([1, 1, 1, 3, 0, 9, 1, 1, 4, 7])
# Batch labels: tensor([7, 1, 2, 4, 1, 6, 9, 0, 5, 8])
# Batch predicted: tensor([4, 4, 1, 4, 1, 4, 4, 1, 9, 4])
# Batch labels: tensor([6, 1, 8, 6, 1, 4, 2, 6, 2, 7])
# Batch predicted: tensor([1, 4, 1, 7, 7, 1, 4, 4, 4, 4])
# Batch labels: tensor([2, 2, 0, 8, 6, 9, 1, 7, 1, 8])
# Batch predicted: tensor([1, 1, 4, 8, 1, 7, 9, 4, 4, 8])
# Batch labels: tensor([8, 0, 7, 3, 8, 0, 3, 4, 3, 7])
# Batch predicted: tensor([2, 4, 8, 4, 1, 4, 4, 1, 1, 4])
# Batch labels: tensor([7, 9, 2, 3, 1, 9, 1, 9, 6, 3])
# Batch predicted: tensor([8, 7, 4, 4, 7, 4, 4, 4, 1, 4])
# Batch labels: tensor([3, 3, 1, 0, 6, 1, 4, 1, 0, 0])
# Batch predicted: tensor([1, 1, 9, 1, 4, 9, 9, 4, 4, 1])
# Batch labels: tensor([1, 1, 6, 5, 4, 6, 2, 0, 7, 9])
# Batch predicted: tensor([1, 1, 4, 4, 9, 1, 8, 4, 7, 4])
# Batch labels: tensor([8, 7, 2, 0, 6, 8, 1, 4, 3, 7])
# Batch predicted: tensor([4, 7, 1, 7, 1, 4, 4, 2, 4, 8])
# Batch labels: tensor([0, 6, 1, 8, 5, 7, 8, 4, 8, 3])
# Batch predicted: tensor([1, 4, 1, 0, 4, 4, 8, 2, 2, 0])
# Batch labels: tensor([9, 9, 9, 8, 7, 6, 6, 3, 5, 1])
# Batch predicted: tensor([1, 1, 8, 1, 4, 9, 1, 1, 1, 1])
# Batch labels: tensor([5, 9, 1, 4, 1, 5, 7, 0, 1, 5])
# Batch predicted: tensor([4, 1, 9, 4, 9, 9, 4, 8, 7, 4])
# Batch labels: tensor([2, 0, 8, 8, 5, 6, 7, 3, 2, 4])
# Batch predicted: tensor([4, 1, 4, 1, 1, 4, 4, 4, 0, 4])
# Batch labels: tensor([7, 2, 5, 8, 2, 4, 9, 2, 1, 8])
# Batch predicted: tensor([1, 1, 1, 4, 1, 1, 1, 4, 1, 8])
# Batch labels: tensor([1, 9, 8, 8, 8, 9, 0, 4, 3, 3])
# Batch predicted: tensor([4, 4, 4, 4, 9, 7, 4, 9, 4, 1])
# Batch labels: tensor([1, 8, 4, 6, 3, 3, 5, 2, 2, 8])
# Batch predicted: tensor([4, 4, 4, 8, 1, 1, 7, 1, 1, 7])
# Batch labels: tensor([3, 8, 9, 5, 8, 9, 8, 9, 1, 6])
# Batch predicted: tensor([1, 1, 4, 4, 1, 4, 4, 1, 4, 4])
# Batch labels: tensor([5, 9, 4, 4, 8, 0, 7, 2, 9, 7])
# Batch predicted: tensor([3, 1, 7, 4, 4, 1, 1, 2, 9, 1])
# Batch labels: tensor([4, 1, 6, 4, 4, 9, 1, 2, 5, 6])
# Batch predicted: tensor([1, 4, 7, 4, 1, 9, 4, 1, 1, 4])
# Batch labels: tensor([0, 8, 6, 1, 9, 4, 5, 9, 5, 0])
# Batch predicted: tensor([4, 2, 1, 4, 8, 7, 9, 9, 2, 4])
# Batch labels: tensor([7, 2, 0, 0, 4, 2, 6, 6, 5, 5])
# Batch predicted: tensor([1, 1, 1, 4, 9, 0, 4, 9, 4, 2])
# Batch labels: tensor([2, 8, 1, 7, 3, 1, 4, 5, 6, 5])
# Batch predicted: tensor([0, 7, 8, 4, 2, 4, 7, 1, 2, 4])
# Batch labels: tensor([1, 4, 7, 0, 9, 4, 3, 8, 2, 8])
# Batch predicted: tensor([9, 4, 4, 4, 1, 4, 2, 1, 1, 1])
# Batch labels: tensor([4, 7, 2, 3, 1, 5, 2, 9, 8, 9])
# Batch predicted: tensor([1, 1, 2, 0, 4, 4, 7, 4, 1, 1])
# Batch labels: tensor([7, 9, 5, 1, 4, 0, 8, 2, 3, 8])
# Batch predicted: tensor([2, 1, 4, 4, 4, 4, 1, 9, 4, 8])
# Batch labels: tensor([9, 1, 1, 3, 2, 4, 9, 3, 1, 7])
# Batch predicted: tensor([7, 9, 1, 7, 4, 1, 2, 1, 8, 4])
# Batch labels: tensor([4, 6, 2, 8, 9, 5, 3, 9, 5, 5])
# Batch predicted: tensor([9, 2, 4, 4, 4, 4, 4, 4, 1, 1])
# Batch labels: tensor([6, 7, 2, 4, 6, 3, 1, 0, 7, 2])
# Batch predicted: tensor([9, 7, 4, 7, 4, 1, 1, 4, 4, 7])
# Batch labels: tensor([5, 4, 7, 6, 1, 1, 9, 8, 1, 0])
# Batch predicted: tensor([1, 9, 9, 4, 4, 9, 3, 4, 1, 7])
# Batch labels: tensor([1, 3, 1, 1, 1, 7, 3, 9, 6, 8])
# Batch predicted: tensor([4, 7, 4, 4, 1, 4, 4, 1, 4, 4])
# Batch labels: tensor([4, 6, 8, 4, 9, 4, 7, 9, 7, 6])
# Batch predicted: tensor([1, 9, 4, 1, 4, 1, 9, 1, 1, 1])
# Batch labels: tensor([8, 4, 9, 7, 0, 1, 6, 1, 5, 9])
# Batch predicted: tensor([4, 9, 9, 4, 4, 2, 1, 1, 7, 9])
# Batch labels: tensor([0, 4, 3, 4, 1, 3, 0, 8, 4, 6])
# Batch predicted: tensor([9, 7, 9, 4, 1, 7, 9, 8, 0, 7])
# Batch labels: tensor([2, 2, 6, 5, 3, 6, 2, 1, 1, 8])
# Batch predicted: tensor([9, 1, 4, 7, 4, 1, 1, 7, 8, 4])
# Batch labels: tensor([6, 0, 4, 0, 1, 9, 7, 1, 3, 7])
# Batch predicted: tensor([4, 4, 4, 4, 8, 7, 4, 4, 9, 1])
# Batch labels: tensor([7, 8, 7, 7, 3, 9, 7, 7, 7, 2])
# Batch predicted: tensor([4, 4, 4, 7, 9, 4, 2, 4, 4, 9])
# Batch labels: tensor([1, 2, 8, 6, 4, 0, 7, 9, 8, 6])
# Batch predicted: tensor([7, 4, 1, 4, 4, 4, 1, 1, 2, 4])
# Batch labels: tensor([8, 4, 9, 1, 7, 2, 2, 8, 5, 8])
# Batch predicted: tensor([0, 4, 1, 4, 1, 2, 4, 4, 4, 7])
# Batch labels: tensor([1, 2, 2, 4, 1, 2, 5, 2, 8, 1])
# Batch predicted: tensor([7, 1, 1, 4, 4, 4, 1, 1, 4, 9])
# Batch labels: tensor([8, 1, 8, 6, 0, 2, 4, 1, 3, 6])
# Batch predicted: tensor([1, 4, 4, 9, 9, 9, 9, 9, 1, 9])
# Batch labels: tensor([7, 7, 4, 4, 3, 3, 4, 5, 2, 4])
# Batch predicted: tensor([4, 8, 4, 4, 4, 4, 8, 4, 4, 1])
# Batch labels: tensor([3, 7, 8, 4, 4, 4, 5, 4, 3, 2])
# Batch predicted: tensor([1, 4, 9, 1, 6, 4, 4, 1, 4, 4])
# Batch labels: tensor([8, 4, 5, 5, 4, 1, 4, 2, 5, 1])
# Batch predicted: tensor([9, 7, 1, 7, 4, 4, 9, 4, 9, 4])
# Batch labels: tensor([6, 4, 3, 4, 4, 0, 8, 8, 4, 5])
# Batch predicted: tensor([8, 4, 4, 1, 4, 9, 4, 4, 2, 4])
# Batch labels: tensor([7, 5, 6, 9, 1, 6, 7, 2, 0, 1])
# Batch predicted: tensor([8, 4, 4, 4, 1, 7, 4, 4, 9, 4])
# Batch labels: tensor([4, 5, 6, 0, 0, 2, 7, 5, 6, 0])
# Batch predicted: tensor([1, 1, 1, 4, 1, 2, 9, 7, 4, 7])
# Batch labels: tensor([6, 2, 9, 1, 7, 7, 5, 2, 5, 6])
# Batch predicted: tensor([4, 1, 6, 4, 4, 9, 1, 4, 4, 1])
# Batch labels: tensor([4, 1, 4, 3, 3, 3, 0, 3, 5, 5])
# Batch predicted: tensor([4, 4, 1, 4, 1, 1, 4, 1, 9, 7])
# Batch labels: tensor([8, 9, 7, 3, 1, 3, 3, 3, 4, 4])
# Batch predicted: tensor([9, 9, 4, 1, 4, 2, 8, 1, 2, 9])
# Batch labels: tensor([2, 3, 3, 8, 1, 7, 7, 0, 7, 4])
# Batch predicted: tensor([9, 1, 4, 4, 7, 4, 4, 1, 4, 1])
# Batch labels: tensor([5, 1, 4, 2, 4, 3, 9, 9, 4, 9])
# Batch predicted: tensor([1, 4, 4, 8, 4, 1, 1, 7, 4, 1])
# Batch labels: tensor([9, 1, 8, 1, 6, 7, 5, 5, 4, 9])
# Batch predicted: tensor([1, 4, 9, 1, 9, 2, 1, 4, 4, 2])
# Batch labels: tensor([7, 6, 5, 9, 2, 4, 0, 7, 8, 5])
# Batch predicted: tensor([9, 1, 4, 1, 1, 7, 1, 1, 4, 7])
# Batch labels: tensor([5, 0, 0, 9, 9, 8, 2, 5, 4, 8])
# Batch predicted: tensor([1, 9, 1, 7, 4, 4, 7, 9, 4, 7])
# Batch labels: tensor([3, 6, 3, 6, 0, 6, 6, 6, 9, 6])
# Batch predicted: tensor([4, 1, 9, 7, 4, 1, 7, 1, 9, 8])
# Batch labels: tensor([6, 8, 6, 2, 4, 5, 8, 1, 2, 7])
# Batch predicted: tensor([9, 4, 4, 2, 1, 1, 4, 4, 7, 4])
# Batch labels: tensor([6, 5, 7, 8, 1, 8, 0, 8, 6, 9])
# Batch predicted: tensor([7, 1, 4, 2, 1, 1, 8, 1, 9, 1])
# Batch labels: tensor([2, 8, 9, 4, 0, 9, 4, 9, 5, 7])
# Batch predicted: tensor([1, 1, 1, 8, 1, 1, 1, 1, 4, 7])
# Batch labels: tensor([5, 5, 9, 5, 3, 0, 1, 9, 7, 2])
# Batch predicted: tensor([7, 1, 4, 7, 4, 4, 4, 4, 4, 4])
# Batch labels: tensor([4, 1, 0, 8, 0, 3, 1, 7, 0, 0])
# Batch predicted: tensor([4, 4, 7, 4, 7, 2, 4, 4, 4, 7])
# Batch labels: tensor([4, 8, 6, 2, 4, 0, 0, 9, 0, 8])
# Batch predicted: tensor([1, 4, 4, 9, 4, 4, 2, 4, 9, 1])
# Batch labels: tensor([4, 5, 9, 3, 9, 0, 5, 6, 5, 0])
# Batch predicted: tensor([4, 6, 4, 4, 4, 4, 9, 2, 4, 4])
# Batch labels: tensor([1, 4, 8, 1, 0, 5, 2, 1, 0, 2])
# Batch predicted: tensor([7, 4, 9, 2, 4, 1, 1, 4, 7, 1])
# Batch labels: tensor([8, 1, 5, 6, 7, 7, 2, 6, 2, 5])
# Batch predicted: tensor([7, 4, 9, 4, 1, 7, 8, 1, 1, 4])
# Batch labels: tensor([0, 1, 4, 2, 5, 4, 6, 2, 2, 1])
# Batch predicted: tensor([2, 7, 4, 9, 7, 4, 1, 9, 0, 1])
# Batch labels: tensor([7, 2, 8, 5, 5, 3, 0, 4, 8, 3])
# Batch predicted: tensor([1, 9, 8, 1, 1, 1, 4, 8, 9, 1])
# Batch labels: tensor([7, 6, 3, 8, 1, 0, 1, 3, 3, 0])
# Batch predicted: tensor([1, 7, 1, 4, 4, 4, 1, 4, 7, 4])
# Batch labels: tensor([7, 4, 9, 5, 3, 6, 0, 1, 4, 4])
# Batch predicted: tensor([4, 4, 1, 8, 4, 4, 4, 2, 1, 4])
# Batch labels: tensor([4, 4, 2, 2, 5, 8, 1, 5, 9, 8])
# Batch predicted: tensor([4, 4, 4, 4, 4, 4, 1, 9, 4, 4])
# Batch labels: tensor([1, 1, 5, 3, 9, 9, 7, 6, 5, 0])
# Batch predicted: tensor([4, 7, 1, 4, 1, 4, 4, 1, 1, 1])
# Batch labels: tensor([8, 4, 7, 0, 9, 2, 8, 4, 7, 1])
# Batch predicted: tensor([8, 1, 9, 8, 4, 4, 7, 1, 9, 8])
# Batch labels: tensor([3, 9, 6, 8, 9, 0, 4, 9, 6, 7])
# Batch predicted: tensor([1, 1, 4, 4, 1, 4, 1, 4, 9, 8])
# Batch labels: tensor([8, 9, 4, 8, 9, 7, 2, 5, 3, 7])
# Batch predicted: tensor([1, 1, 1, 1, 1, 4, 1, 9, 4, 1])
# Batch labels: tensor([1, 0, 2, 9, 5, 5, 8, 5, 4, 2])
# Batch predicted: tensor([4, 8, 2, 7, 8, 1, 7, 7, 1, 1])
# Batch labels: tensor([8, 3, 5, 5, 7, 7, 8, 6, 2, 8])
# Batch predicted: tensor([9, 9, 1, 9, 1, 1, 1, 8, 4, 1])
# Batch labels: tensor([2, 3, 5, 6, 8, 0, 2, 3, 7, 0])
# Batch predicted: tensor([4, 1, 1, 8, 4, 4, 8, 9, 1, 7])
# Batch labels: tensor([1, 9, 1, 3, 7, 5, 8, 3, 2, 9])
# Batch predicted: tensor([4, 4, 1, 4, 9, 4, 4, 4, 1, 4])
# Batch labels: tensor([6, 8, 6, 9, 3, 8, 9, 8, 0, 7])
# Batch predicted: tensor([1, 4, 1, 0, 0, 9, 4, 1, 1, 4])
# Batch labels: tensor([8, 5, 0, 0, 1, 3, 9, 1, 5, 3])
# Batch predicted: tensor([4, 9, 9, 1, 4, 4, 9, 1, 4, 4])
# Batch labels: tensor([4, 4, 0, 9, 9, 9, 9, 8, 2, 4])
# Batch predicted: tensor([8, 1, 4, 4, 4, 4, 1, 1, 7, 2])
# Batch labels: tensor([2, 2, 5, 1, 9, 1, 0, 9, 4, 2])
# Batch predicted: tensor([4, 9, 4, 1, 4, 4, 4, 4, 4, 9])
# Batch labels: tensor([1, 6, 0, 3, 7, 6, 3, 1, 8, 6])
# Batch predicted: tensor([4, 1, 8, 7, 2, 2, 7, 9, 9, 4])
# Batch labels: tensor([5, 7, 2, 8, 4, 4, 8, 3, 5, 0])
# Batch predicted: tensor([4, 1, 4, 4, 7, 9, 2, 1, 2, 1])
# Batch labels: tensor([5, 7, 4, 4, 2, 2, 7, 3, 6, 0])
# Batch predicted: tensor([9, 1, 4, 4, 4, 9, 4, 8, 1, 8])
# Batch labels: tensor([2, 7, 6, 2, 3, 0, 7, 7, 8, 1])
# Batch predicted: tensor([9, 9, 7, 4, 9, 4, 4, 4, 4, 4])
# Batch labels: tensor([1, 4, 6, 0, 6, 6, 5, 5, 6, 3])
# Batch predicted: tensor([1, 4, 9, 1, 8, 4, 7, 1, 9, 4])
# Batch labels: tensor([9, 3, 6, 8, 7, 6, 4, 9, 5, 6])
# Batch predicted: tensor([9, 4, 4, 2, 1, 2, 9, 1, 4, 9])
# Batch labels: tensor([4, 1, 6, 3, 8, 2, 3, 9, 8, 5])
# Batch predicted: tensor([1, 2, 4, 7, 4, 9, 4, 1, 1, 1])
# Batch labels: tensor([1, 5, 4, 5, 7, 5, 7, 8, 9, 1])
# Batch predicted: tensor([7, 9, 1, 7, 1, 7, 4, 2, 9, 4])
# Batch labels: tensor([7, 2, 5, 6, 8, 4, 6, 5, 3, 9])
# Batch predicted: tensor([1, 1, 3, 9, 4, 4, 1, 8, 8, 8])
# Batch labels: tensor([9, 8, 5, 5, 6, 4, 5, 9, 7, 3])
# Batch predicted: tensor([2, 1, 1, 9, 7, 4, 9, 2, 2, 4])
# Batch labels: tensor([4, 1, 4, 2, 3, 6, 5, 5, 2, 8])
# Batch predicted: tensor([1, 1, 1, 4, 9, 1, 1, 8, 7, 8])
# Batch labels: tensor([0, 0, 1, 8, 3, 1, 3, 5, 8, 3])
# Batch predicted: tensor([1, 9, 4, 7, 1, 9, 1, 4, 4, 1])
# Batch labels: tensor([8, 5, 8, 6, 3, 5, 5, 5, 0, 9])
# Batch predicted: tensor([9, 4, 9, 9, 7, 9, 7, 4, 8, 4])
# Batch labels: tensor([5, 5, 7, 1, 8, 2, 2, 7, 3, 4])
# Batch predicted: tensor([9, 1, 4, 7, 1, 4, 9, 4, 4, 4])
# Batch labels: tensor([2, 9, 6, 2, 2, 4, 3, 0, 2, 0])
# Batch predicted: tensor([4, 2, 7, 2, 2, 9, 4, 7, 4, 8])
# Batch labels: tensor([1, 3, 2, 2, 7, 0, 1, 0, 7, 7])
# Batch predicted: tensor([4, 1, 1, 9, 1, 4, 7, 7, 1, 4])
# Batch labels: tensor([2, 0, 1, 6, 5, 0, 2, 2, 0, 1])
# Batch predicted: tensor([9, 9, 4, 2, 1, 7, 9, 4, 9, 7])
# Batch labels: tensor([2, 6, 0, 1, 6, 6, 5, 3, 4, 0])
# Batch predicted: tensor([1, 4, 4, 1, 4, 4, 1, 4, 4, 9])
# Batch labels: tensor([0, 9, 1, 0, 2, 5, 9, 7, 8, 6])
# Batch predicted: tensor([7, 9, 1, 4, 1, 4, 1, 4, 4, 4])
# Batch labels: tensor([4, 6, 0, 2, 0, 1, 9, 2, 4, 9])
# Batch predicted: tensor([4, 1, 1, 4, 4, 1, 4, 9, 4, 4])
# Batch labels: tensor([0, 7, 2, 3, 4, 8, 0, 2, 6, 8])
# Batch predicted: tensor([1, 1, 1, 4, 4, 4, 4, 1, 1, 7])
# Batch labels: tensor([9, 7, 1, 9, 3, 7, 2, 7, 9, 6])
# Batch predicted: tensor([1, 2, 9, 4, 4, 2, 4, 9, 1, 1])
# Batch labels: tensor([9, 5, 7, 8, 5, 9, 8, 3, 9, 8])
# Batch predicted: tensor([4, 1, 1, 9, 4, 1, 4, 2, 9, 4])
# Batch labels: tensor([0, 5, 5, 7, 1, 2, 0, 7, 5, 8])
# Batch predicted: tensor([4, 2, 1, 7, 4, 4, 1, 1, 4, 1])
# Batch labels: tensor([2, 2, 5, 3, 9, 3, 1, 9, 3, 1])
# Batch predicted: tensor([7, 1, 7, 4, 1, 4, 0, 1, 1, 4])
# Batch labels: tensor([4, 3, 4, 4, 9, 0, 9, 5, 9, 2])
# Batch predicted: tensor([2, 9, 4, 4, 1, 2, 7, 4, 8, 4])
# Batch labels: tensor([9, 4, 0, 2, 8, 4, 8, 6, 8, 2])
# Batch predicted: tensor([2, 4, 4, 4, 1, 1, 1, 6, 4, 8])
# Batch labels: tensor([0, 5, 9, 6, 9, 5, 1, 3, 4, 4])
# Batch predicted: tensor([1, 4, 9, 7, 4, 4, 4, 7, 7, 1])
# Batch labels: tensor([2, 7, 2, 4, 4, 0, 2, 8, 4, 5])
# Batch predicted: tensor([0, 4, 2, 7, 1, 2, 9, 7, 4, 4])
# Batch labels: tensor([1, 2, 6, 8, 1, 7, 2, 8, 7, 4])
# Batch predicted: tensor([8, 4, 4, 1, 1, 1, 1, 4, 0, 7])
# Batch labels: tensor([3, 3, 0, 3, 7, 2, 5, 6, 1, 7])
# Batch predicted: tensor([4, 4, 1, 9, 1, 7, 1, 4, 1, 2])
# Batch labels: tensor([9, 0, 2, 3, 9, 8, 9, 5, 0, 0])
# Batch predicted: tensor([4, 9, 1, 1, 4, 4, 4, 1, 9, 1])
# Batch labels: tensor([7, 6, 3, 3, 8, 1, 4, 0, 1, 5])
# Batch predicted: tensor([4, 6, 4, 9, 8, 1, 1, 9, 4, 2])
# Batch labels: tensor([4, 3, 2, 6, 0, 8, 8, 6, 3, 3])
# Batch predicted: tensor([7, 1, 1, 4, 4, 7, 1, 9, 1, 4])
# Batch labels: tensor([2, 9, 7, 5, 1, 6, 0, 5, 9, 9])
# Batch predicted: tensor([7, 1, 4, 9, 1, 2, 9, 4, 4, 1])
# Batch labels: tensor([4, 5, 9, 4, 8, 3, 3, 2, 5, 1])
# Batch predicted: tensor([1, 4, 8, 4, 1, 1, 2, 6, 1, 9])
# Batch labels: tensor([9, 5, 5, 8, 1, 8, 9, 7, 0, 6])
# Batch predicted: tensor([4, 4, 4, 1, 9, 1, 4, 1, 4, 1])
# Batch labels: tensor([3, 2, 0, 2, 6, 9, 3, 9, 1, 6])
# Batch predicted: tensor([4, 9, 4, 9, 1, 1, 4, 8, 4, 8])
# Batch labels: tensor([6, 7, 2, 6, 3, 2, 5, 5, 2, 7])
# Batch predicted: tensor([9, 1, 1, 1, 4, 4, 4, 1, 2, 9])
# Batch labels: tensor([5, 2, 0, 8, 0, 7, 7, 1, 7, 4])
# Batch predicted: tensor([4, 1, 8, 4, 4, 1, 2, 4, 4, 8])
# Batch labels: tensor([0, 2, 2, 6, 1, 5, 9, 7, 6, 2])
# Batch predicted: tensor([2, 7, 4, 1, 7, 4, 4, 4, 4, 9])
# Batch labels: tensor([7, 0, 5, 6, 0, 1, 1, 8, 4, 5])
# Batch predicted: tensor([1, 1, 2, 9, 1, 4, 9, 4, 1, 4])
# Batch labels: tensor([3, 1, 2, 4, 8, 9, 8, 1, 7, 2])
# Batch predicted: tensor([2, 1, 2, 9, 9, 1, 2, 4, 4, 1])
# Batch labels: tensor([7, 2, 3, 2, 6, 7, 9, 4, 0, 1])
# Batch predicted: tensor([4, 1, 4, 4, 1, 1, 4, 4, 1, 4])
# Batch labels: tensor([0, 4, 5, 0, 8, 0, 7, 6, 1, 0])
# Batch predicted: tensor([4, 1, 4, 7, 9, 4, 1, 1, 1, 9])
# Batch labels: tensor([8, 5, 9, 2, 5, 4, 4, 9, 0, 6])
# Batch predicted: tensor([1, 1, 1, 4, 7, 1, 4, 8, 7, 2])
# Batch labels: tensor([1, 2, 5, 1, 6, 7, 1, 5, 8, 8])
# Batch predicted: tensor([4, 4, 2, 1, 4, 4, 4, 1, 1, 4])
# Batch labels: tensor([0, 3, 9, 4, 0, 3, 4, 9, 2, 4])
# Batch predicted: tensor([1, 1, 9, 9, 9, 9, 2, 4, 1, 9])
# Batch labels: tensor([3, 0, 6, 4, 5, 6, 6, 7, 8, 4])
# Batch predicted: tensor([4, 4, 2, 8, 7, 1, 7, 2, 4, 7])
# Batch labels: tensor([8, 8, 3, 2, 8, 0, 2, 5, 6, 8])
# Batch predicted: tensor([8, 4, 4, 1, 4, 4, 7, 1, 1, 4])
# Batch labels: tensor([7, 8, 9, 9, 0, 6, 6, 8, 1, 1])
# Batch predicted: tensor([8, 9, 9, 1, 9, 9, 1, 1, 4, 7])
# Batch labels: tensor([7, 4, 4, 2, 3, 6, 9, 6, 2, 4])
# Batch predicted: tensor([0, 4, 1, 7, 4, 9, 1, 4, 1, 9])
# Batch labels: tensor([1, 8, 2, 3, 1, 6, 8, 6, 8, 5])
# Batch predicted: tensor([4, 1, 4, 1, 4, 4, 1, 1, 4, 1])
# Batch labels: tensor([9, 0, 1, 0, 2, 9, 2, 9, 0, 9])
# Batch predicted: tensor([8, 1, 1, 7, 7, 4, 4, 4, 9, 4])
# Batch labels: tensor([7, 8, 5, 0, 6, 6, 8, 1, 6, 5])
# Batch predicted: tensor([4, 4, 4, 4, 4, 1, 2, 8, 9, 9])
# Batch labels: tensor([8, 7, 9, 2, 1, 6, 7, 5, 6, 3])
# Batch predicted: tensor([1, 4, 7, 4, 1, 4, 4, 4, 9, 1])
# Batch labels: tensor([0, 9, 8, 9, 5, 9, 9, 9, 3, 6])
# Batch predicted: tensor([7, 4, 1, 4, 4, 8, 9, 1, 4, 2])
# Batch labels: tensor([4, 4, 8, 8, 1, 7, 3, 0, 6, 2])
# Batch predicted: tensor([9, 7, 1, 4, 1, 4, 1, 7, 4, 6])
# Batch labels: tensor([4, 8, 2, 2, 9, 2, 2, 9, 7, 4])
# Batch predicted: tensor([4, 1, 4, 4, 9, 4, 1, 4, 1, 9])
# Batch labels: tensor([1, 9, 1, 4, 3, 5, 3, 8, 9, 3])
# Batch predicted: tensor([7, 1, 4, 1, 1, 7, 1, 1, 4, 4])
# Batch labels: tensor([6, 2, 0, 8, 9, 0, 5, 1, 5, 8])
# Batch predicted: tensor([4, 1, 4, 4, 4, 1, 1, 9, 1, 4])
# Batch labels: tensor([2, 1, 2, 3, 2, 4, 8, 4, 0, 6])
# Batch predicted: tensor([7, 9, 4, 1, 2, 4, 7, 8, 4, 1])
# Batch labels: tensor([4, 2, 9, 8, 4, 7, 6, 2, 4, 7])
# Batch predicted: tensor([1, 4, 9, 4, 1, 8, 4, 4, 2, 4])
# Batch labels: tensor([7, 6, 4, 2, 2, 3, 2, 4, 9, 0])
# Batch predicted: tensor([9, 1, 9, 1, 4, 9, 7, 4, 1, 1])
# Batch labels: tensor([0, 9, 6, 5, 8, 5, 2, 4, 8, 8])
# Batch predicted: tensor([9, 8, 9, 4, 9, 1, 7, 4, 9, 7])
# Batch labels: tensor([6, 4, 5, 7, 6, 3, 7, 0, 4, 0])
# Batch predicted: tensor([1, 7, 9, 1, 4, 4, 1, 4, 4, 7])
# Batch labels: tensor([5, 8, 2, 8, 0, 4, 9, 2, 3, 6])
# Batch predicted: tensor([4, 0, 9, 4, 7, 1, 1, 8, 7, 4])
# Batch labels: tensor([8, 1, 6, 0, 8, 4, 3, 1, 4, 5])
# Batch predicted: tensor([1, 9, 1, 9, 1, 4, 4, 4, 9, 6])
# Batch labels: tensor([2, 4, 3, 6, 0, 7, 1, 3, 5, 7])
# Batch predicted: tensor([4, 1, 4, 7, 4, 4, 8, 4, 1, 7])
# Batch labels: tensor([1, 8, 0, 4, 8, 2, 7, 7, 0, 2])
# Batch predicted: tensor([4, 7, 2, 4, 4, 4, 4, 7, 7, 9])
# Batch labels: tensor([2, 4, 3, 3, 1, 6, 1, 6, 4, 6])
# Batch predicted: tensor([4, 7, 7, 4, 9, 7, 2, 1, 1, 9])
# Batch labels: tensor([7, 4, 7, 3, 8, 1, 3, 1, 4, 6])
# Batch predicted: tensor([2, 1, 4, 4, 9, 7, 4, 1, 4, 4])
# Batch labels: tensor([5, 5, 7, 4, 5, 4, 9, 7, 7, 2])
# Batch predicted: tensor([4, 2, 4, 8, 7, 1, 4, 4, 1, 4])
# Batch labels: tensor([3, 3, 6, 7, 4, 1, 6, 1, 0, 6])
# Batch predicted: tensor([8, 7, 1, 1, 4, 4, 2, 1, 1, 1])
# Batch labels: tensor([9, 6, 0, 2, 0, 2, 4, 7, 0, 0])
# Batch predicted: tensor([1, 1, 4, 9, 4, 7, 4, 1, 4, 9])
# Batch labels: tensor([0, 0, 7, 5, 3, 2, 7, 8, 5, 5])
# Batch predicted: tensor([7, 7, 4, 1, 4, 7, 9, 1, 8, 4])
# Batch labels: tensor([2, 2, 8, 9, 1, 2, 2, 0, 3, 4])
# Batch predicted: tensor([1, 4, 1, 0, 4, 4, 9, 4, 8, 9])
# Batch labels: tensor([9, 1, 6, 9, 0, 8, 3, 6, 4, 6])
# Batch predicted: tensor([4, 4, 4, 4, 1, 1, 2, 1, 1, 5])
# Batch labels: tensor([7, 5, 1, 8, 9, 0, 5, 0, 5, 4])
# Batch predicted: tensor([8, 4, 4, 7, 4, 4, 8, 1, 4, 2])
# Batch labels: tensor([3, 8, 5, 2, 0, 8, 5, 9, 2, 5])
# Batch predicted: tensor([4, 1, 8, 7, 4, 9, 1, 4, 7, 4])
# Batch labels: tensor([6, 5, 7, 3, 7, 2, 8, 8, 4, 2])
# Batch predicted: tensor([1, 8, 4, 4, 1, 1, 4, 4, 1, 1])
# Batch labels: tensor([1, 6, 2, 9, 9, 8, 2, 3, 1, 0])
# Batch predicted: tensor([1, 4, 9, 1, 4, 4, 9, 4, 4, 8])
# Batch labels: tensor([5, 2, 3, 7, 9, 5, 9, 1, 1, 3])
# Batch predicted: tensor([7, 4, 4, 4, 4, 1, 4, 2, 9, 4])
# Batch labels: tensor([2, 7, 4, 4, 1, 9, 4, 5, 5, 2])
# Batch predicted: tensor([9, 4, 1, 4, 9, 2, 7, 1, 4, 1])
# Batch labels: tensor([7, 7, 6, 1, 2, 3, 7, 5, 4, 3])
# Batch predicted: tensor([4, 4, 4, 7, 4, 4, 9, 2, 1, 1])
# Batch labels: tensor([7, 7, 0, 0, 1, 4, 4, 3, 7, 9])
# Batch predicted: tensor([4, 8, 4, 4, 1, 4, 1, 4, 4, 1])
# Batch labels: tensor([8, 7, 0, 9, 0, 3, 7, 6, 3, 8])
# Batch predicted: tensor([7, 4, 4, 2, 4, 4, 4, 1, 7, 1])
# Batch labels: tensor([4, 5, 6, 5, 3, 4, 2, 9, 2, 4])
# Batch predicted: tensor([4, 9, 7, 4, 4, 8, 4, 4, 4, 1])
# Batch labels: tensor([9, 2, 0, 1, 1, 3, 7, 9, 5, 1])
# Batch predicted: tensor([4, 1, 9, 8, 4, 7, 4, 9, 2, 8])
# Batch labels: tensor([6, 0, 3, 3, 7, 2, 4, 5, 2, 3])
# Batch predicted: tensor([7, 1, 2, 4, 7, 8, 4, 7, 1, 1])
# Batch labels: tensor([6, 3, 3, 0, 4, 4, 3, 8, 1, 2])
# Batch predicted: tensor([1, 9, 8, 1, 4, 1, 8, 4, 9, 9])
# Batch labels: tensor([3, 2, 7, 1, 4, 5, 6, 8, 6, 6])
# Batch predicted: tensor([8, 2, 4, 4, 4, 9, 9, 1, 4, 4])
# Batch labels: tensor([5, 4, 2, 9, 9, 3, 2, 0, 4, 1])
# Batch predicted: tensor([9, 9, 4, 7, 1, 4, 1, 6, 4, 4])
# Batch labels: tensor([5, 5, 6, 6, 5, 6, 9, 7, 9, 4])
# Batch predicted: tensor([1, 9, 4, 1, 4, 1, 1, 1, 9, 1])
# Batch labels: tensor([8, 3, 1, 9, 8, 1, 9, 0, 3, 0])
# Batch predicted: tensor([4, 7, 8, 1, 4, 1, 8, 1, 4, 9])
# Batch labels: tensor([4, 7, 7, 2, 6, 5, 6, 9, 7, 7])
# Batch predicted: tensor([9, 4, 4, 7, 9, 1, 7, 2, 9, 1])
# Batch labels: tensor([5, 7, 0, 8, 6, 7, 8, 3, 8, 9])
# Batch predicted: tensor([4, 4, 4, 1, 1, 4, 2, 1, 4, 1])
# Batch labels: tensor([3, 2, 9, 2, 7, 4, 1, 9, 7, 0])
# Batch predicted: tensor([4, 1, 2, 4, 9, 1, 1, 4, 1, 7])
# Batch labels: tensor([8, 1, 2, 0, 6, 5, 1, 4, 2, 8])
# Batch predicted: tensor([1, 0, 4, 9, 8, 4, 4, 7, 4, 0])
# Batch labels: tensor([2, 8, 3, 3, 1, 4, 9, 8, 1, 1])
# Batch predicted: tensor([1, 1, 4, 7, 4, 4, 9, 4, 4, 1])
# Batch labels: tensor([7, 9, 9, 4, 6, 8, 5, 3, 2, 2])
# Batch predicted: tensor([1, 4, 4, 1, 1, 8, 1, 4, 4, 4])
# Batch labels: tensor([3, 8, 5, 1, 9, 7, 9, 1, 5, 3])
# Batch predicted: tensor([4, 1, 1, 1, 1, 1, 1, 1, 1, 4])
# Batch labels: tensor([1, 0, 3, 8, 9, 2, 0, 8, 0, 7])
# Batch predicted: tensor([4, 4, 1, 9, 1, 1, 1, 8, 4, 9])
# Batch labels: tensor([9, 4, 8, 3, 0, 7, 0, 7, 0, 5])
# Batch predicted: tensor([4, 9, 9, 4, 1, 7, 1, 9, 1, 4])
# Batch labels: tensor([5, 4, 3, 0, 9, 9, 0, 2, 2, 0])
# Batch predicted: tensor([4, 8, 7, 9, 4, 1, 4, 4, 1, 4])
# Batch labels: tensor([8, 4, 4, 5, 2, 2, 1, 1, 5, 5])
# Batch predicted: tensor([4, 2, 4, 4, 4, 7, 4, 9, 2, 7])
# Batch labels: tensor([4, 3, 4, 0, 8, 4, 8, 2, 5, 6])
# Batch predicted: tensor([9, 4, 4, 4, 7, 1, 9, 9, 4, 2])
# Batch labels: tensor([5, 1, 7, 2, 4, 0, 5, 6, 8, 7])
# Batch predicted: tensor([9, 4, 4, 1, 7, 9, 2, 9, 9, 1])
# Batch labels: tensor([6, 3, 1, 3, 6, 6, 4, 5, 5, 5])
# Batch predicted: tensor([4, 9, 4, 1, 4, 1, 2, 4, 4, 1])
# Batch labels: tensor([1, 8, 7, 3, 0, 2, 5, 1, 1, 1])
# Batch predicted: tensor([9, 1, 7, 0, 7, 2, 1, 4, 4, 4])
# Batch labels: tensor([6, 7, 2, 1, 2, 3, 9, 8, 3, 1])
# Batch predicted: tensor([8, 4, 4, 2, 9, 4, 0, 9, 4, 1])
# Batch labels: tensor([7, 4, 8, 4, 7, 5, 8, 6, 0, 3])
# Batch predicted: tensor([7, 1, 7, 9, 7, 1, 4, 4, 1, 4])
# Batch labels: tensor([0, 8, 3, 4, 4, 9, 4, 6, 1, 5])
# Batch predicted: tensor([8, 7, 1, 4, 9, 4, 7, 9, 1, 2])
# Batch labels: tensor([7, 7, 9, 0, 1, 3, 1, 3, 2, 4])
# Batch predicted: tensor([4, 9, 4, 9, 4, 9, 7, 7, 2, 4])
# Batch labels: tensor([0, 7, 8, 3, 1, 6, 2, 1, 8, 8])
# Batch predicted: tensor([2, 1, 1, 1, 4, 9, 1, 4, 4, 7])
# Batch labels: tensor([1, 9, 7, 5, 3, 2, 9, 0, 6, 8])
# Batch predicted: tensor([4, 4, 9, 1, 4, 9, 1, 4, 4, 4])
# Batch labels: tensor([4, 1, 5, 7, 2, 4, 7, 0, 4, 9])
# Batch predicted: tensor([9, 4, 4, 1, 4, 1, 1, 4, 7, 1])
# Batch labels: tensor([0, 7, 0, 6, 7, 1, 8, 5, 8, 8])
# Batch predicted: tensor([8, 4, 7, 4, 0, 1, 4, 1, 9, 1])
# Batch labels: tensor([7, 0, 0, 3, 2, 5, 7, 0, 6, 4])
# Batch predicted: tensor([9, 4, 1, 7, 4, 9, 1, 9, 1, 8])
# Batch labels: tensor([4, 9, 1, 8, 6, 3, 9, 4, 9, 3])
# Batch predicted: tensor([9, 4, 9, 4, 4, 8, 4, 9, 4, 7])
# Batch labels: tensor([3, 7, 5, 9, 7, 7, 4, 5, 8, 2])
# Batch predicted: tensor([4, 4, 1, 9, 1, 4, 1, 9, 4, 1])
# Batch labels: tensor([8, 9, 5, 3, 1, 9, 2, 2, 0, 1])
# Batch predicted: tensor([1, 4, 1, 4, 1, 7, 9, 1, 4, 4])
# Batch labels: tensor([1, 8, 1, 1, 9, 8, 9, 9, 0, 2])
# Batch predicted: tensor([4, 1, 0, 4, 1, 4, 1, 1, 4, 1])
# Batch labels: tensor([6, 9, 1, 9, 0, 1, 9, 2, 9, 9])
# Batch predicted: tensor([9, 1, 4, 1, 8, 4, 4, 4, 8, 9])
# Batch labels: tensor([9, 0, 9, 9, 2, 1, 7, 0, 5, 6])
# Batch predicted: tensor([4, 1, 7, 4, 4, 4, 7, 4, 4, 4])
# Batch labels: tensor([3, 9, 8, 3, 0, 2, 7, 7, 4, 8])
# Batch predicted: tensor([4, 4, 2, 4, 9, 4, 4, 9, 7, 4])
# Batch labels: tensor([3, 0, 5, 2, 3, 5, 7, 6, 6, 6])
# Batch predicted: tensor([9, 4, 7, 4, 6, 4, 1, 4, 4, 2])
# Batch labels: tensor([5, 6, 5, 4, 5, 8, 8, 0, 9, 7])
# Batch predicted: tensor([1, 4, 4, 1, 7, 4, 2, 4, 1, 4])
# Batch labels: tensor([9, 0, 6, 9, 6, 1, 4, 7, 9, 0])
# Batch predicted: tensor([8, 4, 4, 0, 7, 1, 4, 7, 1, 1])
# Batch labels: tensor([3, 5, 4, 7, 6, 9, 8, 2, 3, 9])
# Batch predicted: tensor([2, 4, 1, 7, 4, 4, 2, 4, 4, 1])
# Batch labels: tensor([3, 3, 7, 8, 3, 5, 5, 9, 6, 1])
# Batch predicted: tensor([2, 4, 2, 2, 4, 2, 1, 3, 4, 9])
# Batch labels: tensor([4, 7, 4, 8, 7, 7, 1, 3, 0, 3])
# Batch predicted: tensor([1, 2, 4, 1, 2, 9, 4, 2, 1, 4])
# Batch labels: tensor([2, 5, 4, 9, 3, 5, 4, 7, 0, 3])
# Batch predicted: tensor([4, 1, 2, 1, 1, 1, 8, 8, 1, 8])
# Batch labels: tensor([7, 0, 2, 1, 5, 8, 7, 3, 5, 7])
# Batch predicted: tensor([4, 9, 2, 9, 4, 1, 4, 4, 1, 7])
# Batch labels: tensor([8, 5, 7, 8, 1, 5, 4, 7, 0, 8])
# Batch predicted: tensor([9, 4, 1, 4, 1, 4, 9, 8, 1, 4])
# Batch labels: tensor([3, 2, 9, 7, 4, 1, 6, 5, 9, 8])
# Batch predicted: tensor([8, 9, 7, 0, 4, 1, 1, 9, 8, 7])
# Batch labels: tensor([5, 5, 4, 1, 0, 9, 4, 4, 3, 0])
# Batch predicted: tensor([4, 4, 1, 7, 1, 4, 4, 1, 1, 2])
# Batch labels: tensor([4, 8, 0, 8, 2, 9, 5, 9, 7, 4])
# Batch predicted: tensor([4, 8, 7, 4, 1, 4, 1, 1, 4, 7])
# Batch labels: tensor([6, 7, 9, 2, 9, 3, 7, 7, 8, 2])
# Batch predicted: tensor([1, 4, 4, 1, 9, 4, 9, 4, 7, 1])
# Batch labels: tensor([2, 0, 2, 5, 3, 6, 4, 7, 2, 3])
# Batch predicted: tensor([1, 7, 4, 4, 9, 1, 1, 5, 4, 2])
# Batch labels: tensor([7, 8, 7, 2, 5, 0, 0, 7, 0, 9])
# Batch predicted: tensor([4, 4, 1, 1, 1, 8, 4, 4, 4, 4])
# Batch labels: tensor([6, 1, 0, 3, 9, 7, 4, 9, 1, 6])
# Batch predicted: tensor([9, 4, 1, 9, 1, 9, 7, 7, 4, 7])
# Batch labels: tensor([8, 1, 2, 3, 3, 5, 4, 8, 9, 7])
# Batch predicted: tensor([9, 4, 0, 4, 8, 8, 1, 4, 4, 2])
# Batch labels: tensor([4, 4, 1, 2, 4, 9, 8, 7, 9, 5])
# Batch predicted: tensor([4, 8, 8, 9, 4, 7, 4, 1, 4, 9])
# Batch labels: tensor([1, 2, 1, 6, 6, 4, 5, 7, 4, 5])
# Batch predicted: tensor([1, 8, 4, 1, 1, 4, 4, 4, 9, 4])
# Batch labels: tensor([8, 5, 2, 8, 7, 8, 2, 3, 6, 1])
# Batch predicted: tensor([4, 1, 4, 4, 0, 1, 1, 1, 2, 1])
# Batch labels: tensor([3, 3, 1, 5, 1, 9, 0, 9, 2, 0])
# Batch predicted: tensor([1, 2, 9, 4, 9, 2, 9, 4, 1, 1])
# Batch labels: tensor([6, 2, 4, 8, 5, 7, 6, 1, 2, 9])
# Batch predicted: tensor([4, 4, 1, 4, 8, 9, 2, 4, 9, 7])
# Batch labels: tensor([4, 5, 0, 3, 3, 7, 7, 7, 1, 4])
# Batch predicted: tensor([9, 4, 1, 7, 1, 7, 4, 9, 8, 1])
# Batch labels: tensor([5, 0, 2, 8, 5, 0, 0, 6, 2, 0])
# Batch predicted: tensor([1, 7, 9, 4, 1, 9, 7, 8, 1, 4])
# Batch labels: tensor([8, 4, 5, 4, 5, 6, 4, 7, 9, 4])
# Batch predicted: tensor([1, 1, 2, 4, 1, 4, 9, 8, 9, 4])
# Batch labels: tensor([2, 0, 6, 4, 0, 0, 6, 4, 6, 1])
# Batch predicted: tensor([2, 9, 4, 1, 4, 4, 9, 7, 1, 1])
# Batch labels: tensor([9, 5, 5, 2, 2, 6, 3, 4, 5, 9])
# Batch predicted: tensor([4, 2, 1, 1, 4, 9, 9, 1, 4, 4])
# Batch labels: tensor([1, 7, 2, 3, 9, 6, 5, 0, 2, 9])
# Batch predicted: tensor([1, 1, 2, 1, 7, 4, 4, 8, 9, 8])
# Batch labels: tensor([7, 1, 7, 2, 2, 0, 8, 6, 4, 3])
# Batch predicted: tensor([4, 2, 8, 4, 4, 4, 9, 1, 1, 4])
# Batch labels: tensor([2, 7, 7, 0, 4, 1, 6, 5, 1, 3])
# Batch predicted: tensor([1, 8, 1, 4, 4, 1, 2, 1, 1, 4])
# Batch labels: tensor([0, 3, 9, 0, 0, 2, 5, 0, 4, 0])
# Batch predicted: tensor([8, 4, 4, 4, 1, 4, 7, 4, 1, 9])
# Batch labels: tensor([1, 9, 8, 4, 9, 4, 2, 4, 3, 3])
# Batch predicted: tensor([9, 2, 4, 7, 9, 1, 1, 1, 8, 4])
# Batch labels: tensor([4, 0, 4, 3, 2, 8, 9, 1, 5, 8])
# Batch predicted: tensor([4, 2, 4, 4, 9, 9, 4, 7, 4, 9])
# Batch labels: tensor([1, 8, 2, 4, 5, 2, 4, 1, 1, 6])
# Batch predicted: tensor([9, 1, 2, 9, 7, 9, 1, 7, 9, 9])
# Batch labels: tensor([6, 8, 5, 2, 2, 5, 0, 8, 2, 3])
# Batch predicted: tensor([8, 4, 4, 9, 4, 7, 1, 1, 1, 1])
# Batch labels: tensor([6, 2, 9, 6, 1, 4, 5, 9, 0, 1])
# Batch predicted: tensor([7, 1, 4, 4, 1, 9, 7, 1, 1, 4])
# Batch labels: tensor([0, 0, 8, 1, 1, 6, 6, 9, 5, 4])
# Batch predicted: tensor([4, 1, 1, 9, 1, 4, 1, 2, 1, 7])
# Batch labels: tensor([1, 7, 8, 6, 9, 1, 7, 6, 0, 9])
# Batch predicted: tensor([9, 4, 4, 1, 4, 8, 9, 4, 1, 1])
# Batch labels: tensor([3, 5, 3, 2, 5, 3, 4, 9, 7, 1])
# Batch predicted: tensor([4, 7, 1, 8, 4, 7, 7, 1, 9, 2])
# Batch labels: tensor([4, 4, 6, 1, 3, 8, 8, 0, 6, 7])
# Batch predicted: tensor([4, 4, 4, 7, 4, 4, 7, 4, 1, 1])
# Batch labels: tensor([7, 6, 7, 2, 3, 2, 2, 6, 2, 7])
# Batch predicted: tensor([4, 4, 9, 4, 1, 7, 7, 1, 4, 4])
# Batch labels: tensor([4, 0, 3, 6, 2, 6, 3, 3, 0, 9])
# Batch predicted: tensor([9, 4, 4, 1, 1, 2, 4, 8, 4, 4])
# Batch labels: tensor([5, 1, 1, 5, 3, 6, 4, 3, 4, 1])
# Batch predicted: tensor([4, 4, 4, 1, 4, 1, 1, 2, 2, 1])
# Batch labels: tensor([0, 4, 5, 5, 2, 8, 9, 4, 3, 1])
# Batch predicted: tensor([4, 4, 4, 8, 8, 4, 9, 9, 4, 2])
# Batch labels: tensor([8, 0, 1, 3, 3, 4, 4, 2, 9, 7])
# Batch predicted: tensor([7, 1, 4, 4, 1, 1, 2, 1, 4, 7])
# Batch labels: tensor([6, 8, 1, 8, 9, 1, 3, 1, 7, 3])
# Batch predicted: tensor([1, 1, 4, 1, 1, 1, 4, 4, 4, 9])
# Batch labels: tensor([0, 0, 2, 8, 3, 9, 2, 7, 2, 6])
# Batch predicted: tensor([4, 1, 9, 0, 7, 4, 4, 7, 7, 2])
# Batch labels: tensor([0, 1, 6, 1, 6, 7, 5, 5, 2, 5])
# Batch predicted: tensor([4, 4, 1, 4, 1, 8, 1, 4, 1, 4])
# Batch labels: tensor([9, 4, 0, 2, 3, 4, 9, 4, 1, 0])
# Batch predicted: tensor([1, 4, 7, 4, 1, 4, 7, 1, 4, 4])
# Batch labels: tensor([0, 2, 3, 8, 9, 2, 8, 9, 5, 7])
# Batch predicted: tensor([1, 1, 9, 4, 1, 1, 9, 2, 7, 4])
# Batch labels: tensor([9, 1, 4, 6, 2, 8, 4, 4, 8, 9])
# Batch predicted: tensor([2, 4, 4, 4, 1, 4, 7, 4, 4, 9])
# Batch labels: tensor([3, 1, 1, 6, 5, 8, 4, 6, 4, 5])
# Batch predicted: tensor([4, 4, 2, 4, 4, 4, 4, 4, 7, 9])
# Batch labels: tensor([2, 6, 4, 2, 3, 1, 3, 6, 8, 5])
# Batch predicted: tensor([1, 7, 1, 4, 9, 1, 4, 1, 9, 7])
# Batch labels: tensor([2, 2, 7, 1, 6, 2, 5, 9, 2, 8])
# Batch predicted: tensor([1, 4, 1, 1, 2, 1, 9, 7, 1, 1])
# Batch labels: tensor([1, 6, 9, 2, 7, 5, 3, 2, 9, 7])
# Batch predicted: tensor([4, 1, 1, 4, 4, 1, 4, 1, 9, 1])
# Batch labels: tensor([0, 2, 9, 3, 4, 1, 7, 9, 5, 8])
# Batch predicted: tensor([1, 4, 2, 7, 4, 1, 8, 4, 9, 7])
# Batch labels: tensor([9, 7, 3, 4, 0, 9, 7, 4, 2, 4])
# Batch predicted: tensor([4, 9, 4, 1, 1, 1, 4, 9, 1, 1])
# Batch labels: tensor([7, 0, 1, 8, 1, 0, 4, 6, 1, 9])
# Batch predicted: tensor([4, 4, 1, 2, 1, 9, 1, 4, 4, 1])
# Batch labels: tensor([9, 2, 1, 2, 5, 6, 9, 7, 7, 3])
# Batch predicted: tensor([9, 1, 1, 9, 9, 7, 1, 8, 4, 5])
# Batch labels: tensor([4, 2, 0, 2, 5, 6, 7, 3, 7, 9])
# Batch predicted: tensor([4, 4, 1, 4, 1, 4, 1, 9, 1, 1])
# Batch labels: tensor([4, 2, 0, 6, 1, 7, 5, 6, 5, 3])
# Batch predicted: tensor([9, 1, 4, 1, 9, 1, 9, 9, 7, 7])
# Batch labels: tensor([9, 2, 7, 8, 5, 9, 5, 8, 5, 4])
# Batch predicted: tensor([2, 4, 4, 1, 4, 1, 8, 1, 1, 1])
# Batch labels: tensor([3, 7, 9, 8, 1, 2, 2, 8, 9, 3])
# Batch predicted: tensor([1, 4, 4, 1, 4, 1, 1, 7, 4, 7])
# Batch labels: tensor([0, 8, 4, 0, 2, 0, 1, 4, 1, 8])
# Batch predicted: tensor([8, 8, 4, 4, 4, 8, 4, 4, 4, 8])
# Batch labels: tensor([5, 5, 7, 9, 8, 3, 7, 9, 1, 5])
# Batch predicted: tensor([4, 1, 4, 4, 1, 1, 1, 1, 7, 4])
# Batch labels: tensor([6, 9, 8, 7, 2, 0, 9, 0, 8, 5])
# Batch predicted: tensor([1, 4, 1, 4, 7, 1, 4, 4, 4, 9])
# Batch labels: tensor([9, 4, 2, 9, 8, 1, 9, 1, 8, 3])
# Batch predicted: tensor([1, 9, 4, 1, 1, 8, 4, 1, 4, 7])
# Batch labels: tensor([7, 6, 4, 2, 3, 7, 0, 3, 5, 8])
# Batch predicted: tensor([7, 1, 4, 4, 9, 1, 8, 7, 1, 4])
# Batch labels: tensor([8, 8, 7, 9, 6, 2, 7, 4, 5, 7])
# Batch predicted: tensor([7, 4, 2, 1, 8, 2, 2, 8, 9, 4])
# Batch labels: tensor([6, 7, 1, 7, 3, 6, 8, 2, 6, 6])
# Batch predicted: tensor([4, 4, 9, 4, 1, 8, 4, 1, 4, 7])
# Batch labels: tensor([7, 1, 5, 9, 7, 1, 7, 0, 1, 6])
# Batch predicted: tensor([4, 2, 4, 1, 0, 1, 9, 1, 1, 2])
# Batch labels: tensor([3, 3, 9, 0, 1, 2, 3, 2, 2, 5])
# Batch predicted: tensor([9, 1, 7, 4, 7, 7, 1, 1, 9, 4])
# Batch labels: tensor([4, 9, 8, 7, 4, 4, 9, 7, 6, 7])
# Batch predicted: tensor([1, 1, 7, 4, 7, 4, 1, 4, 9, 4])
# Batch labels: tensor([7, 1, 2, 3, 5, 1, 9, 0, 3, 3])
# Batch predicted: tensor([4, 3, 2, 1, 9, 4, 9, 4, 4, 4])
# Batch labels: tensor([1, 5, 6, 6, 2, 4, 6, 8, 8, 9])
# Batch predicted: tensor([9, 4, 1, 4, 4, 9, 1, 4, 4, 2])
# Batch labels: tensor([6, 6, 1, 0, 7, 5, 8, 2, 1, 5])
# Batch predicted: tensor([4, 1, 7, 1, 2, 1, 9, 4, 4, 1])
# Batch labels: tensor([8, 1, 4, 7, 5, 0, 3, 9, 9, 5])
# Batch predicted: tensor([4, 7, 4, 4, 1, 7, 7, 9, 1, 7])
# Batch labels: tensor([2, 8, 4, 1, 9, 0, 4, 4, 8, 2])
# Batch predicted: tensor([4, 4, 1, 1, 1, 4, 4, 9, 9, 1])
# Batch labels: tensor([9, 0, 7, 9, 8, 7, 1, 3, 2, 9])
# Batch predicted: tensor([1, 2, 1, 1, 4, 4, 8, 2, 4, 9])
# Batch labels: tensor([9, 5, 9, 7, 6, 7, 7, 1, 1, 2])
# Batch predicted: tensor([4, 1, 4, 9, 1, 1, 7, 8, 2, 2])
# Batch labels: tensor([4, 2, 0, 6, 8, 7, 6, 2, 2, 9])
# Batch predicted: tensor([7, 9, 7, 1, 4, 2, 7, 4, 1, 4])
# Batch labels: tensor([8, 2, 4, 2, 0, 5, 8, 6, 8, 2])
# Batch predicted: tensor([9, 4, 1, 4, 4, 4, 9, 7, 2, 1])
# Batch labels: tensor([7, 7, 3, 1, 8, 1, 6, 5, 9, 7])
# Batch predicted: tensor([4, 1, 9, 4, 4, 1, 4, 7, 4, 9])
# Batch labels: tensor([8, 9, 6, 4, 8, 1, 9, 4, 0, 4])
# Batch predicted: tensor([1, 4, 8, 4, 7, 4, 9, 1, 1, 4])
# Batch labels: tensor([1, 4, 3, 6, 2, 2, 7, 0, 0, 7])
# Batch predicted: tensor([4, 4, 2, 2, 9, 4, 1, 4, 1, 7])
# Batch labels: tensor([0, 7, 4, 3, 6, 7, 7, 4, 5, 4])
# Batch predicted: tensor([9, 9, 4, 7, 2, 4, 4, 1, 1, 4])
# Batch labels: tensor([3, 5, 5, 4, 7, 1, 0, 7, 7, 1])
# Batch predicted: tensor([9, 1, 4, 2, 4, 7, 7, 4, 1, 2])
# Batch labels: tensor([6, 5, 0, 7, 7, 4, 6, 1, 8, 5])
# Batch predicted: tensor([4, 1, 4, 7, 2, 9, 4, 2, 4, 1])
# Batch labels: tensor([9, 3, 5, 6, 2, 2, 7, 3, 5, 8])
# Batch predicted: tensor([4, 1, 9, 4, 7, 7, 7, 9, 2, 1])
# Batch labels: tensor([1, 0, 6, 8, 7, 8, 8, 5, 7, 5])
# Batch predicted: tensor([7, 1, 8, 4, 4, 7, 4, 4, 1, 7])
# Batch labels: tensor([4, 9, 7, 3, 3, 8, 8, 3, 9, 4])
# Batch predicted: tensor([8, 9, 4, 4, 4, 8, 0, 4, 9, 8])
# Batch labels: tensor([7, 2, 0, 8, 0, 7, 3, 3, 2, 5])
# Batch predicted: tensor([4, 2, 1, 4, 7, 1, 9, 4, 1, 4])
# Batch labels: tensor([2, 4, 4, 0, 4, 8, 2, 4, 0, 6])
# Batch predicted: tensor([4, 4, 9, 4, 4, 1, 4, 9, 4, 4])
# Batch labels: tensor([4, 5, 6, 0, 8, 8, 0, 6, 1, 1])
# Batch predicted: tensor([4, 4, 7, 4, 4, 4, 4, 7, 4, 1])
# Batch labels: tensor([6, 1, 4, 2, 1, 1, 2, 4, 4, 5])
# Batch predicted: tensor([8, 1, 1, 4, 4, 2, 8, 9, 9, 1])
# Batch labels: tensor([5, 8, 8, 5, 1, 8, 2, 3, 3, 9])
# Batch predicted: tensor([4, 9, 8, 4, 4, 9, 4, 4, 1, 4])
# Batch labels: tensor([6, 6, 5, 0, 7, 3, 3, 2, 7, 4])
# Batch predicted: tensor([9, 4, 1, 9, 1, 1, 4, 4, 1, 1])
# Batch labels: tensor([5, 6, 0, 2, 1, 8, 1, 0, 9, 3])
# Batch predicted: tensor([1, 4, 1, 4, 4, 2, 8, 7, 8, 4])
# Batch labels: tensor([1, 0, 5, 4, 2, 3, 3, 6, 7, 6])
# Batch predicted: tensor([4, 1, 9, 4, 7, 4, 4, 4, 9, 4])
# Batch labels: tensor([0, 0, 5, 7, 4, 7, 7, 0, 6, 1])
# Batch predicted: tensor([9, 1, 1, 4, 4, 8, 1, 4, 4, 4])
# Batch labels: tensor([3, 9, 0, 9, 0, 3, 8, 4, 8, 8])
# Batch predicted: tensor([4, 4, 2, 4, 9, 4, 4, 4, 9, 4])
# Batch labels: tensor([4, 1, 0, 2, 2, 4, 1, 1, 2, 4])
# Batch predicted: tensor([1, 4, 1, 7, 2, 1, 4, 4, 1, 4])
# Batch labels: tensor([3, 4, 1, 4, 7, 1, 0, 0, 9, 0])
# Batch predicted: tensor([4, 1, 4, 1, 4, 8, 4, 9, 1, 1])
# Batch labels: tensor([4, 2, 8, 8, 5, 5, 0, 4, 0, 8])
# Batch predicted: tensor([1, 4, 8, 1, 4, 1, 1, 4, 1, 4])
# Batch labels: tensor([6, 2, 5, 9, 2, 9, 1, 1, 5, 4])
# Batch predicted: tensor([4, 8, 7, 9, 8, 4, 4, 8, 8, 9])
# Batch labels: tensor([7, 5, 8, 6, 2, 1, 5, 5, 3, 4])
# Batch predicted: tensor([1, 4, 4, 1, 4, 4, 7, 7, 4, 9])
# Batch labels: tensor([1, 8, 9, 9, 8, 9, 8, 6, 8, 5])
# Batch predicted: tensor([8, 1, 7, 4, 4, 4, 2, 4, 2, 4])
# Batch labels: tensor([8, 9, 4, 6, 2, 6, 3, 7, 4, 0])
# Batch predicted: tensor([1, 4, 4, 9, 1, 9, 4, 1, 4, 1])
# Batch labels: tensor([0, 1, 7, 5, 1, 5, 9, 3, 1, 6])
# ...
# Batch predicted: tensor([7, 1, 2, 4, 9, 4, 1, 4, 4, 1])
# Batch labels: tensor([4, 8, 2, 0, 6, 6, 8, 6, 3, 1])
# Batch predicted: tensor([1, 4, 1, 1, 4, 4, 2, 1, 1, 4])
# Batch labels: tensor([1, 8, 6, 7, 0, 5, 4, 3, 2, 1])
# Batch predicted: tensor([4, 4, 9, 4, 1, 4, 2, 4, 9, 1])
# Batch labels: tensor([7, 8, 2, 0, 1, 7, 4, 8, 7, 6])
# Batch predicted: tensor([9, 8, 4, 7, 7, 9, 1, 9, 1, 4])
# Batch labels: tensor([6, 7, 0, 6, 4, 9, 2, 3, 2, 1])
# Batch predicted: tensor([1, 1, 9, 1, 4, 1, 4, 8, 9, 4])
# Batch labels: tensor([3, 8, 6, 8, 1, 9, 6, 7, 6, 5])
# Batch predicted: tensor([1, 4, 4, 4, 9, 4, 4, 1, 1, 4])
# Batch labels: tensor([0, 6, 0, 1, 3, 1, 1, 5, 3, 4])
# Batch predicted: tensor([9, 7, 7, 4, 4, 1, 4, 4, 4, 4])
# Batch labels: tensor([3, 3, 8, 1, 6, 6, 1, 8, 8, 6])
# Batch predicted: tensor([4, 2, 9, 9, 1, 4, 9, 2, 8, 2])
# Batch labels: tensor([2, 7, 4, 6, 8, 9, 3, 3, 5, 5])
# Batch predicted: tensor([2, 4, 7, 1, 1, 4, 4, 2, 4, 2])
# Batch labels: tensor([3, 1, 4, 1, 9, 5, 1, 7, 7, 7])
# Batch predicted: tensor([2, 9, 9, 9, 4, 4, 9, 4, 4, 4])
# Batch labels: tensor([5, 2, 3, 3, 6, 6, 6, 4, 0, 7])
# Batch predicted: tensor([4, 4, 9, 7, 4, 1, 9, 1, 8, 7])
# Batch labels: tensor([1, 7, 3, 0, 8, 1, 2, 4, 1, 2])
# Batch predicted: tensor([9, 4, 1, 4, 1, 4, 4, 4, 9, 4])
# Batch labels: tensor([2, 4, 9, 8, 2, 8, 7, 6, 3, 4])
# Batch predicted: tensor([1, 4, 4, 1, 9, 9, 1, 4, 7, 8])
# Batch labels: tensor([7, 2, 3, 1, 5, 3, 0, 4, 3, 4])
# Batch predicted: tensor([9, 4, 8, 4, 4, 4, 1, 1, 4, 1])
# Batch labels: tensor([9, 4, 7, 9, 1, 7, 8, 3, 1, 8])
# Batch predicted: tensor([2, 7, 4, 8, 1, 1, 1, 7, 4, 1])
# Batch labels: tensor([3, 2, 5, 7, 2, 7, 9, 6, 8, 6])
# Batch predicted: tensor([4, 4, 4, 1, 4, 4, 0, 4, 9, 9])
# Batch labels: tensor([8, 6, 5, 9, 0, 4, 8, 5, 6, 4])
# Batch predicted: tensor([4, 4, 1, 7, 4, 4, 1, 1, 4, 4])
# Batch labels: tensor([3, 8, 0, 4, 8, 6, 7, 2, 7, 1])
# Batch predicted: tensor([4, 8, 4, 7, 1, 1, 4, 4, 8, 1])
# Batch labels: tensor([7, 4, 1, 2, 4, 2, 2, 8, 7, 2])
# Batch predicted: tensor([1, 7, 8, 4, 9, 7, 1, 4, 1, 9])
# Batch labels: tensor([2, 6, 7, 5, 6, 8, 9, 9, 6, 5])
# Batch predicted: tensor([9, 9, 1, 8, 2, 4, 9, 1, 7, 9])
# Batch labels: tensor([2, 9, 8, 7, 2, 3, 3, 7, 4, 3])
# Batch predicted: tensor([4, 4, 4, 9, 4, 1, 1, 4, 1, 1])
# Batch labels: tensor([2, 1, 9, 0, 1, 5, 3, 2, 6, 5])
# Batch predicted: tensor([1, 1, 4, 4, 9, 9, 1, 7, 1, 8])
# Batch labels: tensor([9, 1, 5, 4, 3, 6, 2, 8, 9, 7])
# Batch predicted: tensor([1, 7, 7, 1, 4, 4, 9, 4, 9, 4])
# Batch labels: tensor([8, 0, 8, 9, 1, 2, 5, 7, 2, 0])
# Batch predicted: tensor([9, 7, 0, 4, 9, 9, 9, 1, 4, 1])
# Batch labels: tensor([6, 6, 1, 6, 3, 1, 5, 0, 3, 7])
# Batch predicted: tensor([4, 4, 9, 4, 4, 1, 2, 4, 1, 8])
# Batch labels: tensor([4, 6, 5, 6, 4, 8, 3, 4, 5, 5])
# Batch predicted: tensor([1, 4, 7, 1, 4, 4, 2, 4, 4, 4])
# Batch labels: tensor([0, 6, 6, 7, 5, 0, 9, 9, 6, 1])
# Batch predicted: tensor([1, 2, 4, 1, 9, 1, 9, 9, 7, 9])
# Batch labels: tensor([0, 4, 6, 3, 6, 9, 3, 6, 6, 8])
# Batch predicted: tensor([8, 9, 4, 4, 1, 8, 7, 7, 8, 4])
# Batch labels: tensor([2, 1, 0, 1, 9, 3, 7, 4, 3, 0])
# Batch predicted: tensor([1, 4, 9, 7, 4, 1, 7, 4, 4, 1])
# Batch labels: tensor([2, 7, 6, 4, 3, 0, 8, 2, 0, 0])
# Batch predicted: tensor([4, 9, 4, 7, 7, 1, 4, 1, 7, 0])
# Batch labels: tensor([9, 6, 6, 6, 8, 7, 4, 1, 8, 1])
# Batch predicted: tensor([8, 4, 7, 4, 1, 1, 4, 2, 4, 1])
# Batch labels: tensor([2, 2, 4, 8, 5, 2, 6, 5, 3, 9])
# Batch predicted: tensor([4, 1, 8, 9, 4, 7, 4, 1, 9, 4])
# Batch labels: tensor([1, 0, 7, 2, 4, 4, 0, 0, 6, 2])
# Batch predicted: tensor([1, 4, 4, 1, 1, 4, 4, 7, 8, 1])
# Batch labels: tensor([2, 4, 0, 5, 9, 7, 1, 8, 4, 5])
# Batch predicted: tensor([9, 1, 4, 1, 7, 1, 4, 1, 4, 4])
# Batch labels: tensor([5, 9, 8, 5, 7, 8, 0, 9, 8, 9])
# Batch predicted: tensor([4, 7, 2, 4, 1, 4, 1, 4, 1, 7])
# Batch labels: tensor([1, 6, 3, 8, 0, 3, 4, 4, 8, 4])
# Batch predicted: tensor([4, 1, 4, 4, 4, 4, 4, 8, 1, 9])
# Batch labels: tensor([8, 9, 8, 6, 0, 0, 8, 2, 7, 4])
# Batch predicted: tensor([1, 2, 9, 1, 1, 1, 4, 4, 1, 1])
# Batch labels: tensor([2, 5, 6, 0, 5, 8, 4, 1, 9, 0])
# Batch predicted: tensor([9, 1, 4, 4, 8, 4, 9, 4, 9, 4])
# Batch labels: tensor([1, 4, 4, 8, 4, 9, 6, 0, 7, 7])
# Batch predicted: tensor([9, 2, 4, 8, 4, 7, 4, 1, 7, 1])
# Batch labels: tensor([6, 8, 9, 6, 2, 0, 4, 9, 4, 9])
# Batch predicted: tensor([1, 1, 2, 9, 2, 4, 4, 6, 4, 4])
# Batch labels: tensor([3, 9, 6, 6, 7, 0, 9, 7, 1, 8])
# Batch predicted: tensor([1, 2, 7, 4, 1, 1, 4, 4, 4, 4])
# Batch labels: tensor([6, 0, 6, 7, 4, 1, 9, 4, 6, 7])
# Batch predicted: tensor([1, 7, 1, 9, 7, 1, 4, 4, 9, 4])
# Batch labels: tensor([9, 8, 3, 9, 2, 1, 2, 7, 6, 1])
# Batch predicted: tensor([1, 4, 1, 7, 1, 4, 7, 1, 4, 2])
# Batch labels: tensor([0, 0, 5, 6, 0, 4, 3, 2, 8, 8])
# Batch predicted: tensor([1, 7, 4, 9, 4, 7, 1, 4, 7, 9])
# Batch labels: tensor([0, 6, 9, 5, 2, 8, 7, 0, 6, 5])
# Batch predicted: tensor([1, 4, 1, 9, 4, 1, 4, 1, 1, 4])
# Batch labels: tensor([9, 7, 2, 3, 6, 9, 6, 2, 2, 4])
# Batch predicted: tensor([1, 4, 1, 7, 7, 4, 2, 1, 4, 4])
# Batch labels: tensor([1, 0, 5, 0, 8, 9, 3, 5, 9, 3])
# Batch predicted: tensor([1, 4, 4, 1, 1, 9, 9, 4, 4, 4])
# Batch labels: tensor([8, 1, 6, 3, 7, 5, 6, 2, 0, 2])
# Batch predicted: tensor([1, 4, 1, 1, 4, 7, 1, 4, 4, 1])
# Batch labels: tensor([8, 2, 8, 7, 7, 8, 1, 0, 8, 9])
# Batch predicted: tensor([4, 1, 2, 1, 1, 8, 1, 9, 7, 2])
# Batch labels: tensor([7, 0, 3, 8, 0, 5, 9, 5, 8, 4])
# Batch predicted: tensor([7, 7, 4, 1, 4, 4, 1, 1, 4, 7])
# Batch labels: tensor([2, 0, 9, 2, 2, 4, 4, 9, 2, 2])
# Batch predicted: tensor([1, 4, 4, 1, 4, 4, 1, 7, 1, 7])
# Batch labels: tensor([2, 5, 1, 3, 2, 0, 0, 4, 0, 6])
# Batch predicted: tensor([1, 4, 1, 1, 7, 9, 9, 4, 4, 4])
# Batch labels: tensor([5, 8, 0, 5, 8, 6, 4, 8, 5, 2])
# Batch predicted: tensor([1, 4, 1, 8, 4, 4, 4, 2, 4, 1])
# Batch labels: tensor([9, 7, 9, 7, 1, 0, 1, 9, 6, 9])
# Batch predicted: tensor([1, 0, 4, 7, 4, 4, 7, 7, 4, 4])
# Batch labels: tensor([2, 7, 9, 4, 4, 0, 6, 2, 4, 1])
# Batch predicted: tensor([1, 4, 8, 1, 1, 4, 4, 4, 4, 8])
# Batch labels: tensor([3, 7, 2, 8, 5, 9, 0, 3, 2, 3])
# Batch predicted: tensor([4, 4, 9, 9, 4, 1, 1, 4, 1, 1])
# Batch labels: tensor([2, 7, 6, 3, 2, 5, 9, 0, 5, 9])
# Batch predicted: tensor([1, 0, 4, 4, 7, 1, 9, 1, 4, 8])
# Batch labels: tensor([9, 8, 7, 7, 4, 8, 6, 5, 2, 3])
# Batch predicted: tensor([4, 4, 4, 1, 1, 1, 4, 1, 4, 4])
# Batch labels: tensor([1, 0, 4, 1, 8, 8, 4, 9, 4, 4])
# Batch predicted: tensor([1, 4, 1, 2, 1, 8, 4, 1, 4, 9])
# Batch labels: tensor([3, 3, 9, 2, 0, 1, 1, 8, 4, 4])
# Batch predicted: tensor([7, 1, 1, 4, 9, 1, 9, 4, 8, 4])
# Batch labels: tensor([8, 3, 2, 9, 5, 7, 6, 2, 5, 4])
# Batch predicted: tensor([7, 4, 4, 1, 4, 1, 1, 4, 1, 1])
# Batch labels: tensor([7, 3, 3, 9, 0, 1, 5, 9, 3, 7])
# Batch predicted: tensor([9, 1, 7, 4, 7, 9, 4, 1, 7, 1])
# Batch labels: tensor([6, 0, 4, 2, 2, 5, 6, 3, 8, 9])
# Batch predicted: tensor([4, 9, 1, 9, 9, 6, 9, 2, 4, 4])
# Batch labels: tensor([5, 6, 1, 4, 5, 4, 6, 7, 2, 1])
# Batch predicted: tensor([1, 8, 1, 7, 9, 1, 4, 1, 8, 0])
# Batch labels: tensor([0, 2, 0, 4, 9, 8, 8, 9, 1, 1])
# Batch predicted: tensor([8, 4, 1, 1, 4, 1, 7, 7, 1, 8])
# Batch labels: tensor([5, 0, 0, 8, 7, 1, 7, 4, 5, 4])
# Batch predicted: tensor([4, 8, 4, 4, 7, 4, 4, 4, 8, 1])
# Batch labels: tensor([3, 3, 2, 0, 6, 6, 0, 1, 3, 9])
# Batch predicted: tensor([7, 8, 4, 0, 4, 4, 7, 4, 4, 9])
# Batch labels: tensor([8, 3, 7, 8, 9, 4, 8, 9, 0, 9])
# Batch predicted: tensor([1, 4, 4, 7, 4, 9, 1, 5, 4, 4])
# Batch labels: tensor([7, 1, 6, 2, 9, 5, 6, 9, 3, 9])
# Batch predicted: tensor([7, 4, 1, 4, 9, 1, 4, 1, 9, 4])
# Batch labels: tensor([8, 7, 7, 1, 6, 5, 3, 1, 3, 1])
# Batch predicted: tensor([4, 9, 4, 4, 7, 4, 1, 8, 4, 1])
# Batch labels: tensor([2, 7, 1, 8, 2, 0, 9, 7, 9, 8])
# Batch predicted: tensor([1, 1, 1, 9, 8, 4, 4, 1, 1, 1])
# Batch labels: tensor([8, 6, 7, 3, 7, 1, 3, 9, 0, 9])
# Batch predicted: tensor([8, 4, 4, 4, 9, 1, 1, 1, 1, 4])
# Batch labels: tensor([3, 6, 7, 2, 7, 3, 0, 5, 9, 7])
# Batch predicted: tensor([9, 2, 9, 4, 8, 4, 4, 4, 8, 8])
# Batch labels: tensor([5, 5, 0, 6, 5, 1, 8, 2, 7, 5])
# Batch predicted: tensor([1, 4, 4, 9, 4, 1, 1, 8, 8, 4])
# Batch labels: tensor([9, 0, 0, 0, 8, 8, 7, 3, 7, 8])
# Batch predicted: tensor([1, 9, 8, 4, 4, 1, 4, 4, 1, 1])
# Batch labels: tensor([9, 3, 7, 9, 7, 8, 7, 9, 8, 5])
# Batch predicted: tensor([4, 4, 1, 7, 9, 1, 4, 4, 4, 1])
# Batch labels: tensor([4, 8, 3, 7, 6, 3, 8, 2, 1, 9])
# Batch predicted: tensor([7, 4, 1, 4, 1, 4, 4, 4, 9, 3])
# Batch labels: tensor([5, 7, 3, 9, 5, 5, 8, 7, 3, 5])
# Batch predicted: tensor([9, 9, 1, 2, 7, 2, 4, 7, 7, 4])
# Batch labels: tensor([3, 5, 9, 7, 6, 7, 3, 6, 4, 3])
# Batch predicted: tensor([1, 4, 4, 4, 4, 5, 4, 7, 9, 9])
# Batch labels: tensor([9, 4, 2, 1, 9, 6, 0, 2, 6, 7])
# Batch predicted: tensor([7, 1, 1, 1, 4, 1, 9, 1, 4, 4])
# Batch labels: tensor([4, 7, 9, 0, 7, 4, 3, 5, 3, 1])
# Batch predicted: tensor([1, 4, 7, 4, 4, 2, 4, 7, 1, 4])
# Batch labels: tensor([1, 2, 6, 8, 2, 1, 7, 8, 5, 9])
# Batch predicted: tensor([2, 1, 1, 4, 1, 7, 1, 4, 4, 4])
# Batch labels: tensor([6, 1, 1, 5, 0, 6, 0, 9, 2, 6])
# Batch predicted: tensor([1, 4, 1, 4, 9, 4, 7, 1, 1, 7])
# Batch labels: tensor([5, 8, 9, 5, 5, 6, 2, 9, 1, 5])
# Batch predicted: tensor([1, 7, 8, 1, 1, 4, 8, 8, 4, 4])
# Batch labels: tensor([8, 8, 7, 1, 7, 3, 5, 4, 9, 7])
# Batch predicted: tensor([8, 4, 4, 4, 7, 9, 7, 4, 1, 4])
# Batch labels: tensor([5, 2, 9, 9, 4, 7, 4, 1, 3, 8])
# Batch predicted: tensor([2, 1, 1, 9, 2, 4, 4, 9, 8, 4])
# Batch labels: tensor([7, 9, 0, 4, 5, 7, 5, 2, 8, 7])
# Batch predicted: tensor([9, 1, 7, 4, 4, 4, 9, 4, 4, 1])
# Batch labels: tensor([6, 9, 6, 9, 3, 8, 5, 6, 6, 9])
# Batch predicted: tensor([1, 1, 4, 4, 4, 4, 1, 9, 1, 4])
# Batch labels: tensor([5, 7, 8, 0, 5, 0, 7, 4, 8, 2])
# Batch predicted: tensor([4, 4, 9, 1, 1, 9, 4, 4, 9, 9])
# Batch labels: tensor([5, 1, 3, 2, 2, 6, 2, 1, 7, 4])
# Batch predicted: tensor([4, 1, 0, 4, 1, 9, 4, 4, 2, 4])
# Batch labels: tensor([6, 3, 1, 3, 7, 2, 1, 3, 7, 0])
# Batch predicted: tensor([1, 4, 4, 2, 8, 4, 4, 4, 8, 1])
# Batch labels: tensor([8, 4, 4, 5, 7, 9, 5, 4, 3, 9])
# Batch predicted: tensor([2, 4, 4, 7, 2, 4, 9, 1, 9, 4])
# Batch labels: tensor([6, 8, 2, 3, 3, 1, 6, 1, 7, 0])
# Batch predicted: tensor([8, 7, 1, 1, 4, 2, 1, 4, 1, 4])
# Batch labels: tensor([3, 4, 2, 9, 4, 5, 8, 2, 7, 0])
# Batch predicted: tensor([4, 9, 4, 4, 7, 7, 1, 9, 8, 8])
# Batch labels: tensor([9, 6, 8, 0, 8, 2, 8, 5, 7, 7])
# Batch predicted: tensor([4, 4, 4, 4, 4, 4, 7, 4, 9, 4])
# Batch labels: tensor([2, 2, 0, 0, 0, 7, 4, 1, 6, 6])
# Batch predicted: tensor([1, 7, 4, 4, 1, 1, 1, 9, 2, 7])
# Batch labels: tensor([8, 8, 9, 0, 9, 0, 1, 3, 3, 0])
# Batch predicted: tensor([1, 7, 9, 7, 9, 2, 9, 4, 1, 2])
# Batch labels: tensor([9, 6, 6, 2, 6, 3, 4, 0, 8, 4])
# Batch predicted: tensor([4, 4, 4, 9, 1, 4, 4, 7, 4, 1])
# Batch labels: tensor([1, 4, 0, 6, 5, 0, 9, 9, 9, 9])
# Batch predicted: tensor([4, 2, 1, 1, 9, 4, 1, 9, 4, 4])
# Batch labels: tensor([1, 2, 3, 5, 4, 2, 9, 6, 0, 9])
# Batch predicted: tensor([7, 9, 4, 4, 4, 0, 4, 9, 4, 4])
# Batch labels: tensor([6, 6, 8, 0, 6, 1, 4, 6, 8, 0])
# Batch predicted: tensor([4, 4, 1, 1, 4, 1, 7, 9, 4, 7])
# Batch labels: tensor([5, 4, 1, 2, 0, 9, 6, 4, 2, 4])
# Batch predicted: tensor([9, 2, 1, 4, 4, 7, 4, 7, 4, 4])
# Batch labels: tensor([6, 5, 9, 7, 7, 4, 6, 5, 0, 1])
# Batch predicted: tensor([1, 4, 3, 4, 1, 4, 1, 1, 4, 9])
# Batch labels: tensor([9, 0, 3, 1, 9, 0, 9, 7, 8, 6])
# Batch predicted: tensor([4, 7, 4, 8, 1, 4, 1, 1, 2, 4])
# Batch labels: tensor([7, 6, 8, 2, 4, 5, 3, 0, 3, 2])
# Batch predicted: tensor([4, 2, 1, 1, 4, 7, 4, 2, 1, 9])
# Batch labels: tensor([1, 7, 5, 9, 3, 4, 5, 7, 1, 5])
# Batch predicted: tensor([1, 4, 1, 4, 4, 1, 9, 4, 4, 8])
# Batch labels: tensor([0, 1, 1, 1, 9, 7, 5, 4, 9, 7])
# Batch predicted: tensor([4, 4, 1, 4, 1, 9, 4, 4, 4, 4])
# Batch labels: tensor([8, 1, 0, 2, 8, 5, 6, 7, 0, 1])
# Batch predicted: tensor([4, 4, 4, 4, 4, 9, 8, 1, 4, 4])
# Batch labels: tensor([4, 8, 4, 4, 6, 6, 5, 8, 1, 8])
# Batch predicted: tensor([4, 9, 9, 1, 7, 4, 8, 9, 4, 4])
# Batch labels: tensor([4, 6, 5, 9, 2, 2, 1, 4, 9, 1])
# Batch predicted: tensor([9, 9, 4, 1, 4, 4, 9, 1, 4, 1])
# Batch labels: tensor([6, 7, 2, 0, 1, 7, 6, 5, 2, 2])
# Batch predicted: tensor([1, 9, 4, 4, 4, 4, 2, 8, 8, 9])
# Batch labels: tensor([5, 6, 0, 9, 0, 1, 5, 3, 3, 5])
# Batch predicted: tensor([4, 1, 1, 4, 1, 1, 1, 6, 1, 4])
# Batch labels: tensor([8, 7, 5, 6, 5, 8, 0, 5, 9, 4])
# Batch predicted: tensor([4, 1, 1, 4, 4, 4, 1, 4, 9, 7])
# Batch labels: tensor([6, 5, 1, 1, 0, 3, 3, 9, 4, 8])
# Batch predicted: tensor([4, 4, 4, 4, 1, 4, 7, 9, 9, 1])
# Batch labels: tensor([1, 7, 7, 9, 9, 4, 3, 6, 3, 2])
# Batch predicted: tensor([4, 4, 4, 9, 2, 4, 4, 1, 1, 4])
# Batch labels: tensor([8, 2, 7, 6, 7, 0, 2, 1, 2, 9])
# Batch predicted: tensor([4, 9, 2, 9, 4, 0, 4, 1, 1, 1])
# Batch labels: tensor([4, 6, 9, 6, 1, 0, 1, 8, 7, 0])
# Batch predicted: tensor([1, 4, 8, 7, 8, 9, 2, 8, 1, 4])
# Batch labels: tensor([0, 4, 7, 4, 2, 6, 9, 5, 9, 0])
# Batch predicted: tensor([8, 7, 8, 1, 4, 4, 4, 1, 1, 4])
# Batch labels: tensor([7, 4, 5, 8, 1, 4, 7, 9, 9, 8])
# Batch predicted: tensor([4, 4, 2, 6, 4, 1, 1, 4, 1, 7])
# Batch labels: tensor([8, 6, 3, 7, 0, 8, 9, 6, 2, 4])
# Batch predicted: tensor([4, 4, 4, 2, 4, 9, 4, 4, 4, 1])
# Batch labels: tensor([6, 2, 9, 7, 4, 6, 8, 5, 6, 1])
# Batch predicted: tensor([9, 1, 1, 1, 4, 8, 8, 4, 9, 1])
# Batch labels: tensor([3, 5, 9, 9, 1, 3, 2, 0, 3, 0])
# Batch predicted: tensor([4, 4, 9, 9, 1, 4, 1, 8, 4, 4])
# Batch labels: tensor([2, 0, 7, 3, 9, 3, 5, 7, 6, 5])
# Batch predicted: tensor([4, 1, 9, 1, 1, 9, 1, 7, 4, 4])
# Batch labels: tensor([9, 5, 6, 1, 2, 4, 0, 2, 7, 8])
# Batch predicted: tensor([9, 7, 4, 4, 4, 4, 9, 4, 8, 4])
# Batch labels: tensor([4, 4, 0, 9, 5, 9, 2, 9, 3, 2])
# Batch predicted: tensor([9, 1, 2, 9, 4, 4, 4, 1, 0, 7])
# Batch labels: tensor([4, 3, 2, 2, 8, 8, 6, 8, 1, 6])
# Batch predicted: tensor([1, 1, 4, 4, 4, 4, 1, 4, 1, 4])
# Batch labels: tensor([8, 9, 8, 2, 1, 4, 9, 1, 5, 7])
# Batch predicted: tensor([4, 1, 4, 4, 9, 4, 1, 1, 4, 3])
# Batch labels: tensor([1, 6, 0, 1, 5, 2, 8, 1, 1, 3])
# Batch predicted: tensor([1, 0, 4, 4, 4, 1, 1, 9, 4, 1])
# Batch labels: tensor([8, 1, 3, 1, 8, 5, 1, 9, 0, 3])
# Batch predicted: tensor([1, 4, 4, 8, 4, 4, 4, 1, 1, 9])
# Batch labels: tensor([0, 4, 0, 5, 1, 2, 0, 4, 9, 5])
# Batch predicted: tensor([1, 4, 7, 4, 1, 6, 4, 4, 4, 8])
# Batch labels: tensor([1, 2, 2, 7, 8, 7, 2, 4, 5, 3])
# Batch predicted: tensor([4, 1, 9, 4, 9, 1, 7, 4, 1, 1])
# Batch labels: tensor([4, 0, 6, 1, 5, 9, 8, 0, 2, 0])
# Batch predicted: tensor([4, 7, 1, 9, 1, 2, 4, 1, 7, 1])
# Batch labels: tensor([7, 6, 0, 5, 9, 7, 5, 0, 4, 6])
# Batch predicted: tensor([1, 9, 1, 9, 7, 1, 1, 7, 1, 4])
# Batch labels: tensor([0, 6, 3, 6, 8, 1, 1, 8, 9, 7])
# Batch predicted: tensor([4, 4, 4, 4, 4, 1, 4, 9, 4, 4])
# Batch labels: tensor([2, 9, 0, 2, 2, 9, 0, 6, 5, 7])
# Batch predicted: tensor([1, 1, 1, 4, 1, 4, 6, 4, 4, 1])
# Batch labels: tensor([7, 9, 1, 7, 9, 8, 4, 5, 0, 8])
# Batch predicted: tensor([4, 9, 4, 4, 1, 4, 1, 7, 1, 1])
# Batch labels: tensor([0, 2, 5, 2, 1, 4, 4, 8, 9, 7])
# Batch predicted: tensor([4, 9, 9, 4, 4, 4, 4, 4, 1, 4])
# Batch labels: tensor([8, 3, 6, 6, 0, 1, 1, 1, 8, 1])
# Batch predicted: tensor([8, 2, 4, 4, 4, 1, 1, 4, 4, 7])
# Batch labels: tensor([4, 4, 0, 7, 8, 2, 1, 2, 5, 4])
# Batch predicted: tensor([9, 1, 8, 4, 7, 4, 9, 1, 9, 4])
# Batch labels: tensor([6, 0, 5, 7, 4, 4, 3, 9, 5, 8])
# Batch predicted: tensor([2, 7, 1, 6, 4, 1, 1, 8, 4, 4])
# Batch labels: tensor([8, 0, 8, 7, 4, 1, 8, 4, 9, 5])
# Batch predicted: tensor([9, 4, 7, 1, 8, 8, 1, 9, 4, 4])
# Batch labels: tensor([4, 1, 7, 7, 7, 7, 0, 3, 8, 3])
# Batch predicted: tensor([2, 1, 4, 9, 4, 1, 1, 1, 4, 4])
# Batch labels: tensor([3, 0, 5, 7, 0, 8, 0, 0, 9, 2])
# Batch predicted: tensor([4, 4, 4, 1, 7, 1, 4, 2, 9, 4])
# Batch labels: tensor([2, 3, 4, 8, 2, 2, 6, 3, 3, 6])
# Batch predicted: tensor([4, 1, 7, 1, 1, 8, 9, 9, 4, 2])
# Batch labels: tensor([2, 9, 4, 0, 1, 7, 5, 5, 7, 3])
# Batch predicted: tensor([4, 4, 9, 1, 4, 9, 1, 4, 4, 4])
# Batch labels: tensor([0, 4, 2, 0, 7, 5, 8, 0, 8, 2])
# Batch predicted: tensor([8, 1, 2, 4, 8, 1, 2, 1, 4, 4])
# Batch labels: tensor([7, 0, 3, 5, 3, 8, 3, 5, 1, 7])
# Accuracy of the full precision model: 9.35%
